# %%
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python311\python.exe

# %%
# C:\Users\user\AppData\Local\Programs\Python\Python311\python.exe pip install vnstock

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from vnstock import * # Import tất cả các hàm từ thư viện 
import sys
import warnings
warnings.filterwarnings("ignore")
print(sys.executable)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', True)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python311\python.exe

# %%
from vnstock.explorer.vci import Listing, Quote, Company, Finance, Trading
# VCI là nguồn dữ liệu từ CK Vietcap bên cạnh nguồn từ TCBS
from vnstock import Listing
listing = Listing()

# %% [markdown]
# ## 1. Chuẩn bị DL Cổ phiếu

# %%
df_list_symbols_by_exchange = listing.symbols_by_exchange()

# %%
df_list_symbols_by_exchange.columns
# Out:
# Index(['symbol', 'exchange', 'type', 'organ_short_name', 'organ_name',
#        'product_grp_id'],
#       dtype='object')

# %%
categorical_columns = ['exchange', 'type', 'product_grp_id']

# Generate a bar plot for each categorical column
for column in categorical_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(y=column, data=df_list_symbols_by_exchange, order = df_list_symbols_by_exchange[column].value_counts().index)
    plt.title(f'Distribution of {column}')
    plt.xlabel('Count')
    plt.ylabel(column)
    plt.tight_layout()
    plt.show()

# %%
df_stock_short.shape
# Out:
# (697, 4)

# %%
df_stock_short = df_list_symbols_by_exchange[
    df_list_symbols_by_exchange['exchange'].isin(['HSX', 'HNX'])
    & (df_list_symbols_by_exchange['type'] == 'STOCK')
]

# %%
df_stock_short = df_stock_short[['symbol', 'exchange', 'organ_name']]

# %%
df_stock_short.head(3)
# Out:
#    symbol exchange                                      organ_name
# 1     YEG      HSX                  Công ty Cổ phần Tập đoàn Yeah1
# 2     YBM      HSX  Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 14    X20      HNX                             Công ty Cổ phần X20

# %%
df_symbols_by_industries = listing.symbols_by_industries()
df_stock_industry = df_symbols_by_industries[['symbol', 'icb_name2']].rename(columns = {'icb_name2': 'industry'})
df_stock_short = pd.merge(df_stock_short, df_stock_industry, how = 'left', on = 'symbol')

# %%
df_stock_short.head(5)
# Out:
#   symbol exchange                                      organ_name  \
# 0    YEG      HSX                  Công ty Cổ phần Tập đoàn Yeah1
# 1    YBM      HSX  Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 2    X20      HNX                             Công ty Cổ phần X20
# 3    WSS      HNX            Công ty Cổ phần Chứng khoán Phố Wall
# 4    WCS      HNX                 Công ty Cổ phần Bến xe Miền Tây
#
#                      industry
# 0                Truyền thông
# 1           Tài nguyên Cơ bản
# 2     Hàng cá nhân & Gia dụng
# 3           Dịch vụ tài chính
# 4  Hàng & Dịch vụ Công nghiệp

# %% [markdown]
# ## 2. Báo cáo tài chính

# %%
from vnstock import Company
company = Company(symbol='SSI', source='VCI')

# %% [markdown]
# ### 2.1 Thông tin chung

# %%
# Hồ sơ
company.overview()
# Out:
#   symbol     id  issue_share  \
# 0  SSI    74416  1973863918
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               history  \
# 0   - Năm 1999: Công ty Cổ phần Chứng khoán Sài Gòn được thành lập, trụ sở chính tại Thành phố Hồ Chí Minh với 2 nghiệp vụ chính Dịch vụ chứng khoán và Tư vấn đầu tư. Vốn điều lệ ban đầu của công ty là 6 tỷ đồng.  - Năm 2001: Tăng vốn điều lệ tăng lên 9 tỷ đồng.  - Tháng 07/2001: Tăng vốn điều lệ tăng lên 20 tỷ đồng và cung cấp 4 nghiệp vụ chính là tư vấn đầu tư, dịch vụ chứng khoán, tự doanh và lưu ký chứng khoán.  - Tháng 07/2002: Thành lập chi nhánh Hà Nội, mở rộng kinh doanh ra các tỉnh phía Bắc.  - Tháng 04/2004: Tăng vốn điều lệ tăng lên 23 tỷ đồng.  - Tháng 02/2005: Tăng vốn điều lệ tăng lên 26 tỷ đồng.  - Tháng 06/2005: Tăng vốn điều lệ tăng lên 52 tỷ đồng và bổ sung thêm nghiệp vụ Bảo lãnh phát hành chứng khoán.  - Tháng 02/2006: Tăng vốn điều lệ tăng lên 120 tỷ đồng.  - Tháng 05/2006: Tăng vốn điều lệ tăng lên 300 tỷ đồng và trở thành công ty chứng khoán có vốn điều lệ lớn nhất thị trường chứng khoán Việt Nam ở thời điểm bấy giờ.  - Tháng 09/2006: Tăng vốn điều lệ tăng lên 500 tỷ đồng.  - Ngày 15/12/2006: Cổ phiếu của công ty được niêm yết trên sàn HaSTC.  - Tháng 07/2007: Tăng vốn điều lệ tăng lên hơn 799 tỷ đồng.  - Ngày 29/10/2007: Cổ phiếu của công ty được chuyển sang niêm yết tại HOSE.  - Tháng 03/2008: Tăng vốn điều lệ lên 1.199 tỷ đồng.  - Tháng 04/2008: Tăng vốn điều lệ lên 1.366 tỷ đồng.  - Tháng 01/2009: Tăng vốn điều lệ lên 1.533 tỷ đồng.  - Tháng 3/2010: Tăng vốn điều lệ lên 1.755 tỷ đồng.  - Tháng 05/2010: Tăng vốn điều lệ lên 3.511 tỷ đồng.  - Tháng 01/2012: Tăng vốn điều lệ lên 3.526 tỷ đồng.  - Tháng 03/2013: Tăng vốn điều lệ lên 3.537 tỷ đồng.  - Ngày 12/01/2017: Tăng vốn điều lệ lên 4.900.636.840.000 đồng;  - Ngày 30/01/2018: Tăng vốn điều lệ lên 5.000.636.840.000 đồng;  - Ngày 17/12/2018: Đổi tên thành Công ty Cổ phần Chứng khoán SSI;  - Ngày 23/01/2019: Tăng vốn điều lệ lên 5.100.636.840.000 đồng;  - Ngày 18/02/2020: Tăng vốn điều lệ lên 5.200.636.840.000 đồng;  - Ngày 08/05/2020: Tăng vốn điều lệ lên 6.029.456.130.000 đồng;  - Ngày 09/04/2021: Tăng vốn điều lệ lên 6.498.051.040.000 đồng;  - Ngày 22/06/2021: Tăng vốn điều lệ lên 6.573.051.040.000 đồng;  - Ngày 08/10/2021: Tăng vốn điều lệ lên 8.755.976.420.000 đồng;  - Ngày 23/11/2021: Tăng vốn điều lệ lên 9.847.500.220.000 đồng;  - Ngày 18/03/2022: Tăng vốn điều lệ lên 9.947.500.220.000 đồng;  - Ngày 05/09/2022: Tăng vốn điều lệ lên 14.911.301.370.000 đồng;  - Ngày 04/04/2023: Tăng vốn điều lệ lên 15.011.301.370.000 đồng;  - Ngày 28/05/2024: Tăng vốn điều lệ lên 15.111.301.370.000 đồng;  - Ngày 31/10/2024: Tăng vốn điều lệ lên 18.129.500.510.000 đồng;  - Ngày 23/12/2024: Tăng vốn điều lệ lên 19.638.639.180.000 đồng;  - Ngày 15/07/2025: Tăng vốn điều lệ lên 19.738.639.180.000 đồng;
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    company_profile  \
# 0  Công ty Cổ phần Chứng khoán SSI (SSI) có tiền thân là Công ty Cổ phần Chứng khoán Sài Gòn được thành lập vào năm 1999. SSI chuyên cung cấp dịch vụ môi giới, tư vấn và đầu tư tài chính, chứng khoán với mạng lưới hoạt động rộng tại những thành phố lớn như Hà Nội, Thành phố Hồ Chí Minh, Hải Phòng, Nha Trang, Vũng Tàu. Công ty đã cung cấp dịch vụ cho các nhà đầu tư trong nước và nhiều nhà đầu tư nước ngoài danh tiếng với các khách hàng tiêu biểu như Công ty bao gồm Morgan Stanley, HSBC, Vinamilk, Credit Suisse, BIDV, ANZ, Prudential VN, Deutsche Bank. Trong năm 2024, Công ty xếp ở vị trí 2 với 9.18% thị phần môi giới cổ phiếu niêm yết tại HOSE, vị trí thứ 4 với 6.95% thị phần môi giới cổ phiếu niêm yết tại HNX và vị trí thứ 2 với 6.67% thị phần môi giới cổ phiếu đăng ký giao dịch trên thị trường UPCOM. Trên thị trường phái sinh, SSI đứng vị trí thứ 6 thị phần môi giới chứng khoán phái sinh với 3.58%. Doanh thu nghiệp vụ môi giới chứng khoán có giá trị bằng 1.667,43 tỷ đồng, tăng 11.% so với cùng kỳ. Nợ vay ký quỹ/Vốn chủ sở hữu ở mức 81.32%, tăng 18.19%. Lợi nhuận từ FVTPL có giá trị bằng 2.563,13 tỷ đồng, tăng 2.09% và đóng góp 48.9 % tổng lợi nhuận hoạt động. Lợi nhuận trước thuế có giá trị bằng 3.543,53 tỷ đồng, tăng 24.4%. Tỷ lệ sinh lời trên vốn chủ sở hữu (ROE) ở mức 11.39%, tăng 1.28%. Cổ phiếu của Công ty được niêm yết trên sàn HNX vào năm 2006 và chuyển sang sàn HOSE từ năm 2007.
#
#            icb_name3          icb_name2             icb_name4  \
# 0  Dịch vụ tài chính  Dịch vụ tài chính  Môi giới chứng khoán
#
#    financial_ratio_issue_share  charter_capital
# 0  1971872450                   19738639180000

# %%
# Cổ đông
company.shareholders()
# Out:
#           id                                                    share_holder  \
# 0   86085824  Daiwa Securities Group Inc
# 1   86084967  Công ty TNHH Đầu Tư Ndh
# 2   86086919  Deutsche Bank Aktiengesellchaft, London Branch
# 3   86084877  Công ty TNHH Bất Động Sản Sài Gòn Đan Linh
# 4   86088884  En Fund L.P
# 5   86103968  Norges Bank
# 6   86083218  Công ty Cổ phần Đầu tư Đường Mặt Trời
# 7   86112621  VanEck Vietnam ETF
# 8   86112698  Veil Holdings Limited
# 9   86096504  Nguyễn Duy Hưng
# 10  86081385  Beira Limited
# 11  86112712  Venner Group Limited
# 12  86097655  Nguyễn Mạnh Hùng
# 13  86089134  Hanoi Investments Holdings Limited
# 14  86114578  Wareham Group Limited
# 15  86081204  Amersham Industries Limited
# 16  86086860  DC Developing Markets Strategies Public Limited Company
# 17  86112904  Viola Ltd
# 18  86096516  Nguyễn Duy Khánh
# 19  86101102  Nguyễn Thị Thanh Hà
# 20  86088999  Greystanes Limited Company
# 21  86088969  Geaystanes Limited
# 22  86107324  Quỹ Đầu tư Tăng trưởng TVAM
# 23  86096924  Nguyễn Hồng Nam
# 24  86085179  Công Ty TNHH Một Thành Viên Nguyễn Sài Gòn
# 25  86107568  Samsung Vietnam Securities Master Investment Trust
# 26  86107313  Quỹ Đầu tư Tăng trưởng Thiên Việt 2
# 27  86107387  Quỹ ETF SSIAM VNFIN LEAD
# 28  86106974  Quena Ltd
# 29  86081256  Aquila Spc Ltd
# 30  86096394  Nguyễn Đức Thông
# 31  86097453  Nguyễn Kim Long
# 32  86108203  The CH/SE Asia Investment Holdings (Singapore) Private Limited
# 33  86081355  Balestrand Limited
# 34  86112738  Vietnam Co-Investment Fund
# 35  86081703  Bùi Quang Nghiêm
# 36  86091525  Lê Cẩm Bình
# 37  86090908  KB Vietnam Focus Balanced Fund
# 38  86085466  Công ty TNHH Quản lý Quỹ Bảo Việt
# 39  86102903  Nguyễn Văn Khải
# 40  86089015  Grinling International Limited
# 41  86105938  Phạm Viết Muôn
# 42  86095299  Ngô Văn Điểm
# 43  86089727  Hoàng Thị Minh Thủy
# 44  86086067  Đặng Phong Lưu
# 45  86107427  Quỹ ETF SSIAM VNX50
# 46  86099812  Nguyễn Thị Hải Anh
# 47  86102782  Nguyễn Văn Hiển
# 48  86107131  Quỹ Đầu tư Cổ phiếu Năng động Bảo Việt
# 49  86106699  Phùng Thị Ngọc Linh
# 50  86098640  Nguyễn Quốc Cường
# 51  86090235  Hồ Thị Hương Trà
# 52  86089689  Hoàng Thị Khánh Duyên
# 53  86107295  Quỹ Đầu tư Tăng trưởng DFVN
# 54  86110161  Trần Quang Việt
# 55  86089563  Hoàng Nguyễn Quang Huy
# 56  86107245  Quỹ Đầu tư Năng động Eastspring Investments Việt Nam
#
#      quantity  share_own_percent update_date
# 0   301259263  0.153400           2025-02-03
# 1   164263488  0.083640           2025-03-31
# 2   18962224   0.039500           2025-02-03
# 3   76571387   0.038990           2025-02-03
# 4   23429746   0.035650           2021-08-20
# 5   13380000   0.026200           2025-02-03
# 6   11034420   0.025822           2015-06-15
# 7   11264221   0.023000           2025-02-03
# 8   4514027    0.009200           2025-02-03
# 9   16180165   0.008200           2025-06-04
# 10  3031673    0.006300           2025-02-03
# 11  3000000    0.006010           2025-02-03
# 12  10682500   0.005410           2025-06-04
# 13  2593000    0.005090           2025-02-03
# 14  1533250    0.003100           2025-02-03
# 15  1351773    0.002800           2025-02-03
# 16  1250000    0.002600           2025-02-03
# 17  1278000    0.002510           2025-02-03
# 18  4748696    0.002410           2025-06-04
# 19  4430043    0.002240           2025-07-21
# 20  1040450    0.002200           2025-02-03
# 21  1040450    0.002200           2015-12-28
# 22  1050000    0.001747           2020-07-14
# 23  3301346    0.001670           2025-07-31
# 24  3250001    0.001660           2025-02-03
# 25  799000     0.001560           2025-02-03
# 26  870000     0.001448           2020-07-14
# 27  718372     0.001195           2020-07-14
# 28  560000     0.001120           2025-02-03
# 29  551000     0.001080           2025-02-03
# 30  1640000    0.000830           2025-07-31
# 31  1596681    0.000810           2025-07-14
# 32  345000     0.000700           2025-02-03
# 33  370000     0.000700           2025-02-03
# 34  299400     0.000600           2019-01-14
# 35  263174     0.000520           2020-08-10
# 36  212500     0.000410           2025-07-21
# 37  220000     0.000400           2025-02-03
# 38  147048     0.000344           2015-06-15
# 39  160455     0.000310           2025-07-22
# 40  138761     0.000300           2025-02-03
# 41  560636     0.000280           2025-07-14
# 42  145700     0.000150           2025-03-05
# 43  225250     0.000150           2024-02-01
# 44  75068      0.000140           2020-01-20
# 45  68906      0.000115           2020-07-14
# 46  171030     0.000090           2025-06-04
# 47  36500      0.000070           2020-03-18
# 48  36402      0.000061           2020-07-14
# 49  86000      0.000040           2025-06-04
# 50  72000      0.000040           2025-07-21
# 51  18661      0.000030           2018-05-23
# 52  16240      0.000030           2020-07-30
# 53  15000      0.000025           2020-07-14
# 54  4006       0.000008           2018-07-30
# 55  5000       0.000005           2021-11-14
# 56  1020       0.000002           2020-07-14

# %%
# Công ty con
company.subsidiaries()
# Out:
#          id sub_organ_code  ownership_percent  \
# 0  24374434  SSIAM          1.0000
# 1  24374435  SSIIMF         0.7615
# 0  24374436  2040155        0.2000
# 1  24374437  PAN            0.1273
#
#                          organ_name              type
# 0  Công ty TNHH Quản lý quỹ SSI      công ty con
# 1  Quỹ Đầu Tư Thành Viên SSI         công ty con
# 0  Quỹ Đầu Tư Công Nghệ Số Việt Nam  công ty liên kết
# 1  Công ty Cổ phần Tập đoàn PAN      công ty liên kết

# %%
# Lãnh đạo
company.officers(filter_by='all').head() # filter_by='all' hoặc 'working' hoặc 'resigned'
# Out:
#   id         officer_name  \
# 0  7  Nguyễn Duy Hưng
# 1  8  Nguyễn Duy Khánh
# 2  6  Nguyễn Thị Thanh Hà
# 3  9  Nguyễn Hồng Nam
# 4  5  Nguyễn Kim Long
#
#                                                          officer_position  \
# 0  Chủ tịch Hội đồng Quản trị
# 1  Thành viên Hội đồng Quản trị
# 2  Giám đốc Tài chính
# 3  Tổng Giám đốc/Phụ trách Công bố thông tin/Thành viên Hội đồng Quản trị
# 4  Người phụ trách quản trị công ty
#
#                 position_short_name update_date  officer_own_percent  \
# 0  Chủ tịch HĐQT                     2025-07-31  0.00820
# 1  TV HĐQT                           2025-07-31  0.00241
# 2  GĐ Tài chính                      2025-07-21  0.00224
# 3  TGĐ/Phụ trách CBTT/TV HĐQT        2025-07-31  0.00167
# 4  Người phụ trách quản trị công ty  2025-06-03  0.00081
#
#    quantity           type
# 0  16180165  đang làm việc
# 1  4748696   đang làm việc
# 2  4430043   đang làm việc
# 3  3301346   đang làm việc
# 4  1596681   đang làm việc

# %%
# Tin tức
company.news().head(3)
# Out:
#         id  \
# 0  8138107
# 1  8080070
# 2  8079774
#
#                                                                    news_title  \
# 0  SSI: Thông báo về ngày đăng ký cuối cùng tổ chức ĐHĐCĐ bất thường năm 2025
# 1  SSI: Báo cáo tình hình quản trị 6 tháng đầu năm 2025
# 2  SSI: Nghị quyết HĐQT về ngày ĐKCC và thời gian tổ chức ĐHĐCĐBT 2025
#
#   news_sub_title friendly_sub_title  \
# 0
# 1
# 2
#
#                                                                       news_image_url  \
# 0  https://cdn.fiingroup.vn/medialib/127889/I/2024/11/26/09481833153750700_SSI-1.png
# 1  https://cdn.fiingroup.vn/medialib/127889/I/2024/11/26/09481833153750700_SSI-1.png
# 2  https://cdn.fiingroup.vn/medialib/127889/I/2024/11/26/09481833153750700_SSI-1.png
#
#                                                                                                   news_source_link  \
# 0  https://www.hsx.vn/vi/tin-tuc/ssi-thong-bao-ve-ngay-dang-ky-cuoi-cung-to-chuc-dhdcd-bat-thuong-nam-2025/2394923
# 1  https://www.hsx.vn/vi/tin-tuc/ssi-bao-cao-tinh-hinh-quan-tri-6-thang-dau-nam-2025/2393782
# 2  https://www.hsx.vn/vi/tin-tuc/ssi-nghi-quyet-hdqt-ve-ngay-dkcc-va-thoi-gian-to-chuc-dhdcdbt-2025/2393382
#
#   created_at    public_date updated_at lang_code   news_id news_short_content  \
# 0  None       1754385144000  None       vi        11662676
# 1  None       1753975541000  None       vi        11657787
# 2  None       1753899590000  None       vi        11656102
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     news_full_content  \
# 0  <p>Sở Giao dịch Chứng khoán TP.HCM thông báo về ngày đăng ký cuối cùng tổ chức ĐHĐCĐ bất thường năm 2025 của Công ty Cổ phần Chứng khoán SSI như sau:</p><table width="100%" style='text-align: left;border=0'><tr><td colspan='2'><hr /></td></tr><tr><td colspan='2'>Tài liệu đính kèm</td></tr><tr><td> </td><td><a href="https://cmsv5.fiingroup.vn/medialib/FG/2025/2025-08/2025-08-05/SSI/20250804--SSI--TB--ve-ngay-DKCC-to-chuc-DHDCD-bat-thuong-2025.pdf" title="Tải về" download>20250804--SSI--TB--ve-ngay-DKCC-to-chuc-DHDCD-bat-thuong-2025.pdf</a></td></tr></table>
# 1  <p>Công ty Cổ phần Chứng khoán SSI Báo cáo tình hình quản trị 6 tháng đầu năm 2025 như sau:</p><table width="100%" style='text-align: left;border=0'><tr><td colspan='2'><hr /></td></tr><tr><td colspan='2'>Tài liệu đính kèm</td></tr><tr><td> </td><td><a href="https://cmsv5.fiingroup.vn/medialib/FG/2025/2025-07/2025-07-31/SSI/20250730--SSI--Bao-cao-tinh-hinh-quan-tri-cong-ty-6-thang-dau-nam-2025--cbtt_signed.pdf" title="Tải về" download>20250730--SSI--Bao-cao-tinh-hinh-quan-tri-cong-ty-6-thang-dau-nam-2025--cbtt_signed.pdf</a></td></tr></table>
# 2  <p>Công ty Cổ phần Chứng khoán SSI thông báo Nghị quyết HĐQT về ngày ĐKCC và thời gian tổ chức ĐHĐCĐBT 2025 như sau: </p><table width="100%" style='text-align: left;border=0'><tr><td colspan='2'><hr /></td></tr><tr><td colspan='2'>Tài liệu đính kèm</td></tr><tr><td> </td><td><a href="https://cmsv5.fiingroup.vn/medialib/FG/2025/2025-07/2025-07-30/SSI/20250730--SSI--NQ-HDQT-ve-ngay-DKCC-va-thoi-gian-to-chuc-DHDCD-BT-2025_signed.pdf" title="Tải về" download>20250730--SSI--NQ-HDQT-ve-ngay-DKCC-va-thoi-gian-to-chuc-DHDCD-BT-2025_signed.pdf</a></td></tr></table>
#
#    close_price  ref_price  floor  ceiling  price_change_pct
# 0  34650        34000      31650  36350    0.019118
# 1  34200        33900      31550  36250    0.008850
# 2  33900        33300      31000  35600    0.018018

# %%
# Sự kiện
company.events().head(3)
# Out:
#          id                                          event_title  \
# 0  46306062  SSI - Niêm yết bổ sung 301.819.914 cổ phiếu
# 1  31874     Trả cổ tức bằng tiền mặt
# 2  31889     SSI - Trả cổ tức Cả năm, 2016 bằng tiền 1000 VND/CP
#
#                                         en__event_title public_date  \
# 0  SSI- Lists additional 301,819,914 shares              2024-10-30
# 1                                                        2010-05-10
# 2  SSI - Pays Year, 2016 cash dividend at VND1000/share  2017-09-26
#
#    issue_date  \
# 0  2024-10-29
# 1  2010-06-09
# 2  2017-10-20
#
#                                                                                                                                     source_url  \
# 0  http://fiinpro.com/News/Detail/11364803?lang=vi-vn
# 1
# 2  http://cmsv5.stoxplus.com/medialib/Crawler/2017/2017-09/2017-09-26/20170926_20170926--SSI--TB-ngay-DKCC-PH-CP-tra-co-tuc-2016-bang-tien.pdf
#
#   event_list_code  ratio   value record_date exright_date  \
# 0  AIS             0.0    0.0     1753-01-01  1753-01-01
# 1  DIV            NaN    NaN      2010-05-21  2010-05-19
# 2  DIV             0.1    1000.0  2017-10-10  2017-10-09
#
#             event_list_name en__event_list_name
# 0  Niêm yết thêm             Additional Listing
# 1  Trả cổ tức bằng tiền mặt  Cash Dividend
# 2  Trả cổ tức bằng tiền mặt  Cash Dividend

# %% [markdown]
# ### 2.2 Tình hình tài chính

# %%
company.ratio_summary()
# Out:
#   symbol  year_report  length_report    update_date        revenue  \
# 0  SSI    2025         2              1753953362557  2993036323811
#
#    revenue_growth    net_profit  net_profit_growth  ebit_margin       roe  \
# 0  0.297347        969506698143  0.142588           0.602818     0.113831
#
#    ...  rtq4  charter_capital_ratio     rtq10  dividend         ebitda  \
# 0  ...  0     1.449219               2.215575  0         5638724164999
#
#             ebit        le        de   ccc  rtq17
# 0  1804256280178  2.141178  2.215575  None  0
#
# [1 rows x 46 columns]

# %%
from vnstock import Finance

# %%
finance = Finance(symbol='SSI', source='VCI')
df_blance_sheet_VI = finance.balance_sheet(period='quarter', lang='vi', dropna=True)

id_columns = ['CP', 'Năm', 'Kỳ']

df_blance_sheet_melt = pd.melt(
    df_blance_sheet_VI, 
    id_vars=id_columns, 
    var_name='account', 
    value_name='value'
)

# 2. Tạo cột 'report_date' từ cột 'Năm' và 'Kỳ'
# Định dạng YYYY-QQ (ví dụ: 2025-Q2)
df_blance_sheet_melt['report_date'] = df_blance_sheet_melt['Năm'].astype(str) + '-Q' + df_blance_sheet_melt['Kỳ'].astype(str)
df_blance_sheet_melt.rename(columns={'CP': 'symbol'}, inplace=True)
df_blance_sheet_melt.drop(columns=['Năm', 'Kỳ'], inplace=True)
df_blance_sheet_melt = df_blance_sheet_melt[['symbol', 'report_date', 'account', 'value']]
df_blance_sheet_melt = df_blance_sheet_melt[df_blance_sheet_melt['report_date'] >= '2020-Q1']
df_blance_sheet_melt.head(5)
# Out:
#   symbol report_date                  account         value
# 0  SSI    2025-Q2     TÀI SẢN NGẮN HẠN (đồng)  8.955034e+13
# 1  SSI    2025-Q1     TÀI SẢN NGẮN HẠN (đồng)  8.129396e+13
# 2  SSI    2024-Q4     TÀI SẢN NGẮN HẠN (đồng)  7.093239e+13
# 3  SSI    2024-Q3     TÀI SẢN NGẮN HẠN (đồng)  6.428367e+13
# 4  SSI    2024-Q2     TÀI SẢN NGẮN HẠN (đồng)  6.755758e+13

# %%
df_ratio_dict = finance._get_ratio_dict()

# %%
for i, j in enumerate(['a', 'b']):
    print(i)
# Out:
# 0
# 1

# %%
    df_cashflow_statement_vi = finance.cash_flow(period='quarter', lang='vi', dropna=True).head()

# %%
# Get dictionary in both EN and VI of field name
def get_dictionary_field(report_type):
    sample = 'VNM'
    finance = Finance(symbol=sample, source='VCI')
    if report_type == 'Balance Sheet':
        df_sheet_VI = finance.balance_sheet(period='quarter', lang='vi', dropna=False)
        df_sheet_EN = finance.balance_sheet(period='quarter', lang='en', dropna=False)
    elif report_type == 'Income Statement':
        df_sheet_VI = finance.income_statement(period='quarter', lang='vi', dropna=False)
        df_sheet_EN = finance.income_statement(period='quarter', lang='en', dropna=False)
    elif report_type == 'Cash Flow Statement':
        df_sheet_VI = finance.cash_flow(period='quarter', lang='vi', dropna=False)
        df_sheet_EN = finance.cash_flow(period='quarter', lang='en', dropna=False)
    else:
        print("Wrong report name / Not Existed")
    dict_balance_sheet_field = dict(zip(df_sheet_VI.columns, df_sheet_VI.columns))
    return dict_balance_sheet_field
dict_balance_sheet_field = get_dictionary_field('Balance Sheet')
dict_income_statement_field = get_dictionary_field('Income Statement')
dict_cashflow_statement_field = get_dictionary_field('Cash Flow Statement')

# %%
from tqdm import tqdm # Import thư viện tqdm
list_symbol = list(df_exchange_short['symbol'])
all_dataframes = []
dict_report_df = {
    "Balance Sheet": [],
    "Income Statement": [],
    "Cash Flow Statement": []
}
i = 0
for symbol_i in tqdm(list_symbol, desc="Crawl mã CK"):
    finance = Finance(symbol=symbol_i, source='VCI')
    # Lấy dữ liệu Bảng cân đối kế toán theo quý
    df_balance_sheet_vi = finance.balance_sheet(period='quarter', lang='vi', dropna=False)
    df_income_statement_vi = finance.income_statement(period='quarter', lang='vi', dropna=False).head()
    df_cashflow_statement_vi = finance.cash_flow(period='quarter', lang='vi', dropna=False).head()
    if df_balance_sheet_vi.empty:
        print(f"\nKhông có dữ liệu cho mã: {symbol}. Bỏ qua.")
        continue

    df_balance_sheet_vi.reset_index(inplace=True)
    df_income_statement_vi.reset_index(inplace=True)
    df_cashflow_statement_vi.reset_index(inplace=True)
    
    id_columns = ['CP', 'Năm', 'Kỳ']
    dict_statement = {
        "Balance Sheet": df_balance_sheet_vi,
        "Income Statement": df_income_statement_vi,
        "Cash Flow Statement": df_cashflow_statement_vi
    }
    for key_i, df_statement in dict_statement.items():
        df_melted = pd.melt(
            df_balance_sheet_vi, 
            id_vars=id_columns, 
            var_name='account', 
            value_name='value'
        )
        df_melted['report_date'] = df_melted['Năm'].astype(str) + '-Q' + df_melted['Kỳ'].astype(str)
        df_melted.rename(columns={'CP': 'symbol'}, inplace=True)
        df_melted.drop(columns=['Năm', 'Kỳ'], inplace=True)
        df_cleaned = df_melted[['symbol', 'report_date', 'account', 'value']]
        df_final_symbol = df_cleaned[df_cleaned['report_date'] >= '2020-Q1'].copy()
        dict_report_df[key_i].append(df_final_symbol)
    i += 1
    if i == 100:
        print("Finished
        break
# Out:
# Crawl mã CK: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.73s/it]

# %%
len(dict_balance_sheet_field)
# Out:
# 41

# %%
df_balance_sheet_full.shape
# Out:
# (880, 6)

# %%
finance._get_ratio_dict()
# Out:
#               field_name  \
# 0    BSA1
# 1    BSA2
# 2    BSA5
# 3    BSA8
# 4    BSA15
# 5    BSA18
# 6    BSA23
# 7    BSA24
# 8    BSA29
# 9    BSA40
# 10   BSA43
# 11   BSA49
# 12   BSA53
# 13   BSA54
# 14   BSA55
# 15   BSA67
# 16   BSA78
# 17   BSA79
# 18   BSA89
# 19   BSA90
# 20   BSA94
# 21   BSA95
# 22   BSA96
# 23   BSA1
# 24   BSA2
# 25   BSA5
# 26   BSA8
# 27   BSA15
# 28   BSA18
# 29   BSA23
# 30   BSA24
# 31   BSA29
# 32   BSA40
# 33   BSA43
# 34   BSA209
# 35   BSA49
# 36   BSA53
# 37   BSA54
# 38   BSA55
# 39   BSA67
# 40   BSA78
# 41   BSA79
# 42   BSA89
# 43   BSA90
# 44   BSA92
# 45   BSA95
# 46   BSA96
# 47   BSA1
# 48   BSA2
# 49   BSA5
# 50   BSA8
# 51   BSA15
# 52   BSA18
# 53   BSA23
# 54   BSA162
# 55   BSA29
# 56   BSA40
# 57   BSA43
# 58   BSA48
# 59   BSA49
# 60   BSA53
# 61   BSA54
# 62   BSA55
# 63   BSA67
# 64   BSA78
# 65   BSA79
# 66   BSA82
# 67   BSA90
# 68   BSA92
# 69   BSA210
# 70   BSA96
# 71   BSA53
# 72   BSA2
# 73   BSB97
# 74   BSB98
# 75   BSB99
# 76   BSB100
# 77   BSB101
# 78   BSB102
# 79   BSB103
# 80   BSB104
# 81   BSB105
# 82   BSB106
# 83   BSB107
# 84   BSB108
# 85   BSB109
# 86   BSA43
# 87   BSA44
# 88   BSA45
# 89   BSA46
# 90   BSA47
# 91   BSA29
# 92   BSA30
# 93   BSA33
# 94   BSA36
# 95   BSA40
# 96   BSB110
# 97   BSA96
# 98   BSA54
# 99   BSB111
# 100  BSB112
# 101  BSB113
# 102  BSB114
# 103  BSB115
# 104  BSB116
# 105  BSB117
# 106  BSA78
# 107  BSB118
# 108  BSB121
# 109  BSA85
# 110  BSA84
# 111  BSA90
# 112  BSA95
# 113  CFA1
# 114  CFA2
# 115  CFA3
# 116  CFA4
# 117  CFA5
# 118  CFA6
# 119  CFA7
# 120  CFA8
# 121  CFA9
# 122  CFA10
# 123  CFA11
# 124  CFA12
# 125  CFA13
# 126  CFA14
# 127  CFA15
# 128  CFA16
# 129  CFA17
# 130  CFA18
# 131  CFA19
# 132  CFA20
# 133  CFA21
# 134  CFA22
# 135  CFA23
# 136  CFA24
# 137  CFA25
# 138  CFA26
# 139  CFA27
# 140  CFA28
# 141  CFA29
# 142  CFA30
# 143  CFA31
# 144  CFA32
# 145  CFA33
# 146  CFA34
# 147  CFA35
# 148  CFA36
# 149  CFA37
# 150  CFA38
# 151  CFA1
# 152  CFA2
# 153  CFA3
# 154  CFA4
# 155  CFS191
# 156  CFA6
# 157  CFA7
# 158  CFA8
# 159  CFA9
# 160  CFS200
# 161  CFA11
# 162  CFS210
# 163  CFA13
# 164  CFA14
# 165  CFA15
# 166  CFA16
# 167  CFA17
# 168  CFA18
# 169  CFA19
# 170  CFA20
# 171  CFA21
# 172  CFA22
# 173  CFA23
# 174  CFA24
# 175  CFA25
# 176  CFA26
# 177  CFA27
# 178  CFA28
# 179  CFA29
# 180  CFA30
# 181  CFA31
# 182  CFA32
# 183  CFA33
# 184  CFA34
# 185  CFA35
# 186  CFA36
# 187  CFA37
# 188  CFA38
# 189  CFA1
# 190  CFA2
# 191  CFA3
# 192  CFA4
# 193  CFA5
# 194  CFA6
# 195  CFA7
# 196  CFA8
# 197  CFA9
# 198  CFA10
# 199  CFA11
# 200  CFA12
# 201  CFA13
# 202  CFA14
# 203  CFA15
# 204  CFA16
# 205  CFA17
# 206  CFA18
# 207  CFA19
# 208  CFA20
# 209  CFA21
# 210  CFA22
# 211  CFA23
# 212  CFA24
# 213  CFA25
# 214  CFA26
# 215  CFA27
# 216  CFA28
# 217  CFA29
# 218  CFA30
# 219  CFA31
# 220  CFA32
# 221  CFA33
# 222  CFA34
# 223  CFA35
# 224  CFA36
# 225  CFA37
# 226  CFA38
# 227  CFA1
# 228  CFA2
# 229  CFA3
# 230  CFB80
# 231  CFA9
# 232  CFB64
# 233  CFA15
# 234  CFB65
# 235  CFA19
# 236  CFA25
# 237  CFA26
# 238  revenueGrowth
# 239  CFA27
# 240  CFA34
# 241  CFA35
# 242  CFA36
# 243  CFA37
# 244  pb
# 245  CFA38
# 246  revenue
# 247  revenueGrowth
# 248  netProfit
# 249  netProfitGrowth
# 250  ebitMargin
# 251  grossMargin
# 252  netProfitMargin
# 253  roe
# 254  roic
# 255  roa
# 256  ev
# 257  issueShare
# 258  pe
# 259  pb
# 260  ps
# 261  pcf
# 262  eps
# 263  bvps
# 264  evPerEbitda
# 265  currentRatio
# 266  cashRatio
# 267  quickRatio
# 268  interestCoverage
# 269  ae
# 270  at
# 271  fat
# 272  acp
# 273  dso
# 274  dpo
# 275  ccc
# 276  le
# 277  de
# 278  revenue
# 279  revenueGrowth
# 280  netProfit
# 281  netProfitGrowth
# 282  ebitMargin
# 283  grossMargin
# 284  netProfitMargin
# 285  roe
# 286  roic
# 287  roa
# 288  ev
# 289  issueShare
# 290  pe
# 291  ps
# 292  pcf
# 293  eps
# 294  bvps
# 295  evPerEbitda
# 296  currentRatio
# 297  cashRatio
# 298  quickRatio
# 299  interestCoverage
# 300  ae
# 301  at
# 302  fat
# 303  acp
# 304  dso
# 305  dpo
# 306  ccc
# 307  le
# 308  de
# 309  revenue
# 310  revenueGrowth
# 311  netProfit
# 312  netProfitGrowth
# 313  ebitMargin
# 314  grossMargin
# 315  netProfitMargin
# 316  roe
# 317  roic
# 318  roa
# 319  ev
# 320  issueShare
# 321  pe
# 322  pb
# 323  ps
# 324  pcf
# 325  eps
# 326  bvps
# 327  evPerEbitda
# 328  currentRatio
# 329  cashRatio
# 330  quickRatio
# 331  interestCoverage
# 332  ae
# 333  at
# 334  fat
# 335  acp
# 336  dso
# 337  dpo
# 338  ps
# 339  ccc
# 340  le
# 341  de
# 342  revenue
# 343  revenueGrowth
# 344  netProfit
# 345  netProfitGrowth
# 346  ebitMargin
# 347  grossMargin
# 348  netProfitMargin
# 349  roe
# 350  roic
# 351  roa
# 352  ev
# 353  issueShare
# 354  pe
# 355  pb
# 356  ps
# 357  pcf
# 358  eps
# 359  bvps
# 360  evPerEbitda
# 361  currentRatio
# 362  cashRatio
# 363  quickRatio
# 364  interestCoverage
# 365  ae
# 366  at
# 367  fat
# 368  acp
# 369  dso
# 370  dpo
# 371  ccc
# 372  le
# 373  de
# 374  revenue
# 375  revenueGrowth
# 376  netProfit
# 377  netProfitGrowth
# 378  ebitMargin
# 379  netProfitMargin
# 380  grossMargin
# 381  roe
# 382  roic
# 383  roa
# 384  pe
# 385  pb
# 386  pcf
# 387  eps
# 388  bvps
# 389  evPerEbitda
# 390  issueShare
# 391  ev
# 392  BSA1
# 393  BSA2
# 394  BSA5
# 395  BSA8
# 396  BSA10
# 397  BSA159
# 398  BSA16
# 399  BSA22
# 400  BSA23
# 401  le
# 402  de
# 403  ccc
# 404  dpo
# 405  dso
# 406  acp
# 407  fat
# 408  at
# 409  ae
# 410  interestCoverage
# 411  quickRatio
# 412  cashRatio
# 413  currentRatio
# 414  CFA22
# 415  CFA21
# 416  BSA96
# 417  BSA90
# 418  BSA86
# 419  BSA175
# 420  BSA80
# 421  BSA79
# 422  BSA78
# 423  BSA173
# 424  ISA6
# 425  BSA71
# 426  BSA67
# 427  BSA58
# 428  BSA56
# 429  BSA55
# 430  BSA54
# 431  BSA53
# 432  BSA209
# 433  BSA50
# 434  BSA46
# 435  BSA43
# 436  BSA29
# 437  BSA27
# 438  BSA162
# 439  BSA24
# 440  revenue
# 441  revenueGrowth
# 442  netProfit
# 443  netProfitGrowth
# 444  ebitMargin
# 445  netProfitMargin
# 446  grossMargin
# 447  roe
# 448  roic
# 449  roa
# 450  pe
# 451  pb
# 452  ps
# 453  pcf
# 454  eps
# 455  bvps
# 456  evPerEbitda
# 457  issueShare
# 458  ev
# 459  BSA1
# 460  BSA2
# 461  BSA5
# 462  BSA8
# 463  BSA10
# 464  BSA159
# 465  BSA16
# 466  BSA22
# 467  BSA23
# 468  le
# 469  de
# 470  ccc
# 471  dpo
# 472  dso
# 473  acp
# 474  fat
# 475  at
# 476  ae
# 477  interestCoverage
# 478  quickRatio
# 479  cashRatio
# 480  currentRatio
# 481  CFA22
# 482  CFA21
# 483  BSA96
# 484  BSA90
# 485  BSA86
# 486  BSA175
# 487  BSA80
# 488  BSA79
# 489  BSA78
# 490  BSA173
# 491  BSA71
# 492  BSA67
# 493  BSA58
# 494  BSA56
# 495  BSA55
# 496  BSA54
# 497  BSA53
# 498  BSA209
# 499  BSA50
# 500  BSA46
# 501  BSA43
# 502  BSA29
# 503  BSA27
# 504  BSA162
# 505  BSA24
# 506  revenue
# 507  netProfit
# 508  netProfitGrowth
# 509  ebitMargin
# 510  netProfitMargin
# 511  grossMargin
# 512  roe
# 513  roic
# 514  roa
# 515  pe
# 516  pb
# 517  ps
# 518  pcf
# 519  eps
# 520  bvps
# 521  evPerEbitda
# 522  issueShare
# 523  ev
# 524  BSA1
# 525  BSA2
# 526  BSA5
# 527  BSA8
# 528  BSA10
# 529  BSA159
# 530  BSA16
# 531  BSA22
# 532  BSA23
# 533  le
# 534  de
# 535  ccc
# 536  dpo
# 537  dso
# 538  acp
# 539  fat
# 540  at
# 541  ae
# 542  interestCoverage
# 543  quickRatio
# 544  cashRatio
# 545  currentRatio
# 546  CFA22
# 547  CFA21
# 548  BSA96
# 549  BSA90
# 550  BSA86
# 551  BSA175
# 552  BSA80
# 553  BSA79
# 554  BSA78
# 555  BSA173
# 556  BSA71
# 557  BSA67
# 558  BSA58
# 559  BSA56
# 560  BSA55
# 561  BSA54
# 562  BSA53
# 563  BSA209
# 564  BSA50
# 565  BSA46
# 566  BSA43
# 567  BSA29
# 568  BSA27
# 569  BSA162
# 570  BSA24
# 571  revenue
# 572  revenueGrowth
# 573  netProfit
# 574  netProfitGrowth
# 575  ebitMargin
# 576  netProfitMargin
# 577  grossMargin
# 578  roe
# 579  roic
# 580  roa
# 581  pe
# 582  pb
# 583  ps
# 584  pcf
# 585  eps
# 586  bvps
# 587  evPerEbitda
# 588  issueShare
# 589  ev
# 590  BSA1
# 591  BSA2
# 592  BSA5
# 593  BSA8
# 594  BSA10
# 595  BSA159
# 596  BSA16
# 597  BSA22
# 598  BSA23
# 599  le
# 600  de
# 601  ccc
# 602  dpo
# 603  dso
# 604  acp
# 605  fat
# 606  at
# 607  ae
# 608  interestCoverage
# 609  quickRatio
# 610  cashRatio
# 611  currentRatio
# 612  CFA22
# 613  CFA21
# 614  BSA96
# 615  BSA90
# 616  BSA86
# 617  BSA175
# 618  BSA80
# 619  BSA79
# 620  BSA78
# 621  BSA173
# 622  BSA71
# 623  BSA67
# 624  BSA58
# 625  BSA56
# 626  BSA55
# 627  BSA54
# 628  BSA53
# 629  BSA209
# 630  BSA50
# 631  BSA46
# 632  ISA8
# 633  BSA43
# 634  BSA29
# 635  BSA27
# 636  BSA162
# 637  BSA24
# 638  ISI64
# 639  ISI87
# 640  ISA6
# 641  ISA7
# 642  ISA10
# 643  ISI97
# 644  ISA102
# 645  ISA14
# 646  ISA16
# 647  ISA17
# 648  ISA18
# 649  ISA20
# 650  ISA21
# 651  ISA22
# 652  ISA3
# 653  ISA4
# 654  ISA5
# 655  ISS141
# 656  ISS146
# 657  ISS148
# 658  ISS152
# 659  ISA10
# 660  ISA11
# 661  ISA102
# 662  ISA14
# 663  ISA16
# 664  ISA17
# 665  ISA18
# 666  ISA20
# 667  ISA21
# 668  ISA22
# 669  ISA1
# 670  ISA2
# 671  ISA3
# 672  ISA4
# 673  ISA5
# 674  ISA7
# 675  ISA102
# 676  ISA9
# 677  ISA10
# 678  ISA11
# 679  ISA12
# 680  ISA15
# 681  ISA13
# 682  ISA14
# 683  ISA16
# 684  ISA17
# 685  ISA18
# 686  ISA20
# 687  ISA21
# 688  ISA22
# 689  ISB25
# 690  ISB26
# 691  ISB27
# 692  ISB28
# 693  ISB29
# 694  ISB30
# 695  ISB31
# 696  ISB32
# 697  ISB33
# 698  ISB34
# 699  ISB35
# 700  ISB36
# 701  ISB37
# 702  ISB38
# 703  ISB39
# 704  ISB40
# 705  ISB41
# 706  ISA16
# 707  ISA19
# 708  ISA17
# 709  ISA18
# 710  ISA21
# 711  ISA20
# 712  ISA22
# 713  ISA23
# 714  ebitda
# 715  ebit
# 716  dividend
# 717  RTQ17
# 718  fae
# 719  charterCapitalRatio
# 720  ebitda
# 721  ebit
# 722  dividend
# 723  RTQ17
# 724  fae
# 725  charterCapitalRatio
# 726  ebitda
# 727  ebit
# 728  dividend
# 729  RTQ17
# 730  fae
# 731  charterCapitalRatio
# 732  ebitda
# 733  ebit
# 734  dividend
# 735  RTQ17
# 736  fae
# 737  charterCapitalRatio
#
#                                                                        name  \
# 0    TỔNG TÀI SẢN NGẮN HẠN
# 1    Tiền và tương đương tiền
# 2    Giá trị thuần đầu tư ngắn hạn
# 3    Các khoản phải thu
# 4    Hàng tồn kho ròng
# 5    Tài sản lưu động khác
# 6    TỔNG TÀI SẢN DÀI HẠN
# 7    Phải thu dài hạn
# 8    Tài sản cổ định
# 9    Giá trị ròng tài sản đầu tư
# 10   Đầu tư dài hạn
# 11   Tài sản dài hạn khác
# 12   TỔNG TÀI SẢN
# 13   NỢ PHẢI TRẢ
# 14   Nợ ngắn hạn
# 15   Nợ dài hạn
# 16   VỐN CHỦ SỞ HỮU
# 17   Vốn và các quỹ
# 18   Các quỹ khác
# 19   Lãi chưa phân phối
# 20   Vốn Ngân sách nhà nước và quỹ khác
# 21   LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ
# 22   TỔNG NGUỒN VỐN
# 23   TỔNG TÀI SẢN NGẮN HẠN
# 24   Tiền và tương đương tiền
# 25   Giá trị thuần đầu tư ngắn hạn
# 26   Các khoản phải thu
# 27   Hàng tồn kho ròng
# 28   Tài sản lưu động khác
# 29   TỔNG TÀI SẢN DÀI HẠN
# 30   Phải thu dài hạn
# 31   Tài sản cổ định
# 32   Giá trị ròng tài sản đầu tư
# 33   Đầu tư dài hạn
# 34   Lợi thế thương mại
# 35   Tài sản dài hạn khác
# 36   TỔNG TÀI SẢN
# 37   NỢ PHẢI TRẢ
# 38   Nợ ngắn hạn
# 39   Nợ dài hạn
# 40   VỐN CHỦ SỞ HỮU
# 41   Vốn và các quỹ
# 42   Các quỹ khác
# 43   Lãi chưa phân phối
# 44   Vốn Ngân sách nhà nước và quỹ khác
# 45   LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ
# 46   TỔNG NGUỒN VỐN
# 47   TỔNG TÀI SẢN NGẮN HẠN
# 48   Tiền và tương đương tiền
# 49   Giá trị thuần đầu tư ngắn hạn
# 50   Các khoản phải thu
# 51   Hàng tồn kho ròng
# 52   Tài sản lưu động khác
# 53   TỔNG TÀI SẢN DÀI HẠN
# 54   Phải thu dài hạn
# 55   Tài sản cổ định
# 56   Giá trị ròng tài sản đầu tư
# 57   Đầu tư dài hạn
# 58   Lợi thế thương mại
# 59   Tài sản dài hạn khác
# 60   TỔNG TÀI SẢN
# 61   NỢ PHẢI TRẢ
# 62   Nợ ngắn hạn
# 63   Nợ dài hạn
# 64   VỐN CHỦ SỞ HỮU
# 65   Vốn và các quỹ
# 66   Các quỹ khác
# 67   Lãi chưa phân phối
# 68   Vốn Ngân sách nhà nước và quỹ khác
# 69   LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ
# 70   TỔNG NGUỒN VỐN
# 71   Tổng tài sản
# 72   Tiền mặt, vàng bạc, đá quý
# 73   Tiền gửi tại ngân hàng nhà nước Việt Nam
# 74   Tiền gửi tại các TCTD khác và cho vay các TCTD khác
# 75   Chứng khoán kinh doanh
# 76   Chứng khoán kinh doanh
# 77   Dự phòng giảm giá chứng khoán kinh doanh
# 78   Các công cụ tài chính phái sinh và khoản nợ tài chính khác
# 79   Cho vay khách hàng
# 80   Cho vay khách hàng
# 81   Dự phòng rủi ro cho vay khách hàng
# 82   Chứng khoán đầu tư
# 83   Chứng khoán đầu tư sẵn sàng để bán
# 84   Chứng khoán đầu tư giữ đến ngày đáo hạn
# 85   Dự phòng giảm giá chứng khoán đầu tư
# 86   Góp vốn, đầu tư dài hạn
# 87   Đầu tư vào công ty con
# 88   Đầu tư vào công ty liên doanh
# 89   Đầu tư dài hạn khác
# 90   Dự phòng giảm giá đầu tư dài hạn
# 91   Tài sản cổ định
# 92   Tài sản cố định hữu hình
# 93   Tài sản cố định thuê tài chính
# 94   Tài sản cố định vô hình
# 95   Giá trị ròng tài sản đầu tư
# 96   Tài sản Có khác
# 97   NỢ PHẢI TRẢ VÀ VỐN CHỦ SỞ HỮU
# 98   Tổng nợ phải trả
# 99   Các khoản nợ chính phủ và NHNN Việt Nam
# 100  Tiền gửi và vay các Tổ chức tín dụng khác
# 101  Tiền gửi của khách hàng
# 102  Các công cụ tài chính phái sinh và khoản nợ tài chính khác
# 103  Vốn tài trợ, uỷ thác đầu tư của CP và các tổ chức TD khác
# 104  Phát hành giấy tờ có giá
# 105  Các khoản nợ khác
# 106  Vốn chủ sở hữu
# 107  Vốn của tổ chức tín dụng
# 108  Quỹ của tổ chức tín dụng
# 109  Chênh lệch tỷ giá hối đoái
# 110  Chênh lệch đánh giá lại tài sản
# 111  Lợi nhuận chưa phân phối
# 112  Cổ đông thiểu số
# 113  Lãi/Lỗ ròng trước thuế
# 114  Chi phí khấu hao TSCĐ
# 115  Chi phí dự phòng
# 116  Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện
# 117  Lãi/Lỗ từ thanh lý tài sản cố định
# 118  Lãi/Lỗ từ hoạt động đầu tư
# 119  Thu nhập lãi
# 120  Thu lãi và cổ tức
# 121  Lãi/Lỗ trước những thay đổi vốn cố định
# 122  Tăng/Giảm các khoản phải thu
# 123  Tăng/Giảm hàng tồn kho
# 124  Tăng/Giảm các khoản phải trả
# 125  Tăng/Giảm chi phí trả trước
# 126  Chi phí lãi vay đã trả
# 127  Tiền thu nhập doanh nghiệp đã trả
# 128  Tiền thu khác từ các hoạt động kinh doanh
# 129  Tiền chi khác từ các hoạt động kinh doanh
# 130  Lưu chuyển tiền tệ ròng từ các hoạt động SXKD
# 131  Tiền mua tài sản cố định và các tài sản dài hạn khác
# 132  Tiền thu được từ thanh lý tài sản cố định
# 133  Tiền cho vay hoặc mua công cụ nợ
# 134  Tiền thu từ cho vay hoặc thu từ phát hành công cụ nợ
# 135  Đầu tư vào các doanh nghiệp khác
# 136  Tiền thu từ việc bán các khoản đầu tư vào doanh nghiệp khác
# 137  Cổ tức và tiền lãi nhận được
# 138  Lưu chuyển tiền tệ ròng từ hoạt động đầu tư
# 139  Tiền thu từ phát hành cổ phiếu và vốn góp
# 140  Chi trả cho việc mua lại, trả cổ phiếu
# 141  Tiền thu được các khoản đi vay
# 142  Tiền trả các khoản đi vay
# 143  Tiền thanh toán vốn gốc đi thuê tài chính
# 144  Cổ tức đã trả
# 145  Cố tức đã nhận
# 146  Lưu chuyển tiền tệ từ hoạt động tài chính
# 147  Lưu chuyển tiền thuần trong kỳ
# 148  Tiền và tương đương tiền đầu kỳ
# 149  Ảnh hưởng của chênh lệch tỷ giá
# 150  Tiền và tương đương tiền cuối kỳ
# 151  Lãi/Lỗ ròng trước thuế
# 152  Chi phí khấu hao TSCĐ
# 153  Chi phí dự phòng
# 154  Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện
# 155  Lãi/Lỗ từ thanh lý tài sản cố định
# 156  Lãi/Lỗ từ hoạt động đầu tư
# 157  Thu nhập lãi
# 158  Thu lãi và cổ tức
# 159  Lãi/Lỗ trước những thay đổi vốn cố định
# 160  Tăng/Giảm các khoản phải thu
# 161  Tăng/Giảm hàng tồn kho
# 162  Tăng/Giảm các khoản phải trả
# 163  Tăng/Giảm chi phí trả trước
# 164  Chi phí lãi vay đã trả
# 165  Tiền thu nhập doanh nghiệp đã trả
# 166  Tiền thu khác từ các hoạt động kinh doanh
# 167  Tiền chi khác từ các hoạt động kinh doanh
# 168  Lưu chuyển tiền tệ ròng từ các hoạt động SXKD
# 169  Tiền mua tài sản cố định và các tài sản dài hạn khác
# 170  Tiền thu được từ thanh lý tài sản cố định
# 171  Tiền cho vay hoặc mua công cụ nợ
# 172  Tiền thu từ cho vay hoặc thu từ phát hành công cụ nợ
# 173  Đầu tư vào các doanh nghiệp khác
# 174  Tiền thu từ việc bán các khoản đầu tư vào doanh nghiệp khác
# 175  Cổ tức và tiền lãi nhận được
# 176  Lưu chuyển tiền tệ ròng từ hoạt động đầu tư
# 177  Tiền thu từ phát hành cổ phiếu và vốn góp
# 178  Chi trả cho việc mua lại, trả cổ phiếu
# 179  Tiền thu được các khoản đi vay
# 180  Tiền trả các khoản đi vay
# 181  Tiền thanh toán vốn gốc đi thuê tài chính
# 182  Cổ tức đã trả
# 183  Cố tức đã nhận
# 184  Lưu chuyển tiền tệ từ hoạt động tài chính
# 185  Lưu chuyển tiền thuần trong kỳ
# 186  Tiền và tương đương tiền đầu kỳ
# 187  Ảnh hưởng của chênh lệch tỷ giá
# 188  Tiền và tương đương tiền cuối kỳ
# 189  Lãi/Lỗ ròng trước thuế
# 190  Chi phí khấu hao TSCĐ
# 191  Chi phí dự phòng
# 192  Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện
# 193  Lãi/Lỗ từ thanh lý tài sản cố định
# 194  Lãi/Lỗ từ hoạt động đầu tư
# 195  Thu nhập lãi
# 196  Thu lãi và cổ tức
# 197  Lãi/Lỗ trước những thay đổi vốn cố định
# 198  Tăng/Giảm các khoản phải thu
# 199  Tăng/Giảm hàng tồn kho
# 200  Tăng/Giảm các khoản phải trả
# 201  Tăng/Giảm chi phí trả trước
# 202  Chi phí lãi vay đã trả
# 203  Tiền thu nhập doanh nghiệp đã trả
# 204  Tiền thu khác từ các hoạt động kinh doanh
# 205  Tiền chi khác từ các hoạt động kinh doanh
# 206  Lưu chuyển tiền tệ ròng từ các hoạt động SXKD
# 207  Tiền mua tài sản cố định và các tài sản dài hạn khác
# 208  Tiền thu được từ thanh lý tài sản cố định
# 209  Tiền cho vay hoặc mua công cụ nợ
# 210  Tiền thu từ cho vay hoặc thu từ phát hành công cụ nợ
# 211  Đầu tư vào các doanh nghiệp khác
# 212  Tiền thu từ việc bán các khoản đầu tư vào doanh nghiệp khác
# 213  Cổ tức và tiền lãi nhận được
# 214  Lưu chuyển tiền tệ ròng từ hoạt động đầu tư
# 215  Tiền thu từ phát hành cổ phiếu và vốn góp
# 216  Chi trả cho việc mua lại, trả cổ phiếu
# 217  Tiền thu được các khoản đi vay
# 218  Tiền trả các khoản đi vay
# 219  Tiền thanh toán vốn gốc đi thuê tài chính
# 220  Cổ tức đã trả
# 221  Cố tức đã nhận
# 222  Lưu chuyển tiền tệ từ hoạt động tài chính
# 223  Lưu chuyển tiền thuần trong kỳ
# 224  Tiền và tương đương tiền đầu kỳ
# 225  Ảnh hưởng của chênh lệch tỷ giá
# 226  Tiền và tương đương tiền cuối kỳ
# 227  Lãi/Lỗ ròng trước thuế
# 228  Khấu hao TSCĐ
# 229  Dự phòng RR tín dụng
# 230  (Lãi)/lỗ các hoạt động khác
# 231  Lưu chuyển tiền thuần từ HĐKD trước thay đổi VLĐ
# 232  Lưu chuyển tiền thuần từ HĐKD trước thuế
# 233  Tiền thu nhập doanh nghiệp đã trả
# 234  Chi từ các quỹ của TCTD
# 235  Mua sắm TSCĐ
# 236  Tiền thu cổ tức và lợi nhuận được chia
# 237  Lưu chuyển từ hoạt động đầu tư
# 238  Tăng trưởng doanh thu (%)
# 239  Tăng vốn cổ phần từ góp vốn và/hoặc phát hành cổ phiếu
# 240  Lưu chuyển tiền từ hoạt động tài chính
# 241  Lưu chuyển tiền thuần trong kỳ
# 242  Tiền và tương đương tiền
# 243  Ảnh hưởng của chênh lệch tỷ giá
# 244  P/B
# 245  Tiền và tương đương tiền cuối kỳ
# 246  Doanh thu (Tỷ đồng)
# 247  Tăng trưởng doanh thu (%)
# 248  Lợi nhuận sau thuế của Cổ đông công ty mẹ (Tỷ đồng)
# 249  Tăng trưởng lợi nhuận (%)
# 250  EBIT Margin (%)
# 251  Biên lợi nhuận gộp (%)
# 252  Biên lợi nhuận ròng (%)
# 253  ROE (%)
# 254  ROIC (%)
# 255  ROA (%)
# 256  Vốn hóa (Tỷ đồng)
# 257  Số CP lưu hành (Triệu CP)
# 258  P/E
# 259  P/B
# 260  P/S
# 261  P/Cash Flow
# 262  EPS (VND)
# 263  BVPS (VND)
# 264  EV/EBITDA
# 265  Chỉ số thanh toán hiện thời
# 266  Chỉ số thanh toán tiền mặt
# 267  Chỉ số thanh toán nhanh
# 268  Khả năng chi trả lãi vay
# 269  Đòn bẩy tài chính
# 270  Vòng quay tài sản
# 271  Vòng quay TSCĐ
# 272  Số ngày thu tiền bình quân
# 273  Số ngày tồn kho bình quân
# 274  Số ngày thanh toán bình quân
# 275  Chu kỳ tiền
# 276  (Vay NH+DH)/VCSH
# 277  Nợ / Vốn CSH
# 278  Doanh thu (Tỷ đồng)
# 279  Tăng trưởng doanh thu (%)
# 280  Lợi nhuận sau thuế của Cổ đông công ty mẹ (Tỷ đồng)
# 281  Tăng trưởng lợi nhuận (%)
# 282  EBIT Margin (%)
# 283  Biên lợi nhuận gộp (%)
# 284  Biên lợi nhuận ròng (%)
# 285  ROE (%)
# 286  ROIC (%)
# 287  ROA (%)
# 288  Vốn hóa (Tỷ đồng)
# 289  Số CP lưu hành (Triệu CP)
# 290  P/E
# 291  P/S
# 292  P/Cash Flow
# 293  EPS (VND)
# 294  BVPS (VND)
# 295  EV/EBITDA
# 296  Chỉ số thanh toán hiện thời
# 297  Chỉ số thanh toán tiền mặt
# 298  Chỉ số thanh toán nhanh
# 299  Khả năng chi trả lãi vay
# 300  Đòn bẩy tài chính
# 301  Vòng quay tài sản
# 302  Vòng quay TSCĐ
# 303  Số ngày thu tiền bình quân
# 304  Số ngày tồn kho bình quân
# 305  Số ngày thanh toán bình quân
# 306  Chu kỳ tiền
# 307  (Vay NH+DH)/VCSH
# 308  Nợ/VCSH
# 309  Doanh thu (Tỷ đồng)
# 310  Tăng trưởng doanh thu (%)
# 311  Lợi nhuận sau thuế của Cổ đông công ty mẹ (Tỷ đồng)
# 312  Tăng trưởng lợi nhuận (%)
# 313  EBIT Margin (%)
# 314  Biên lợi nhuận gộp (%)
# 315  Biên lợi nhuận ròng (%)
# 316  ROE (%)
# 317  ROIC (%)
# 318  ROA (%)
# 319  Vốn hóa (Tỷ đồng)
# 320  Số CP lưu hành (Triệu CP)
# 321  P/E
# 322  P/B
# 323  P/S
# 324  P/Cash Flow
# 325  EPS (VND)
# 326  BVPS (VND)
# 327  EV/EBITDA
# 328  Chỉ số thanh toán hiện thời
# 329  Chỉ số thanh toán tiền mặt
# 330  Chỉ số thanh toán nhanh
# 331  Khả năng chi trả lãi vay
# 332  Đòn bẩy tài chính
# 333  Vòng quay tài sản
# 334  Vòng quay TSCĐ
# 335  Số ngày thu tiền bình quân
# 336  Số ngày tồn kho bình quân
# 337  Số ngày thanh toán bình quân
# 338  P/S
# 339  Chu kỳ tiền
# 340  (Vay NH+DH)/VCSH
# 341  Nợ/VCSH
# 342  Doanh thu (Tỷ đồng)
# 343  Tăng trưởng doanh thu (%)
# ...
# 480  Chỉ tiêu thanh khoản         42    index  CK
# 481  Chỉ tiêu lưu chuyển tiền tệ  43    tỷ     CK
# 482  Chỉ tiêu lưu chuyển tiền tệ  44    tỷ     CK
# 483  Chỉ tiêu cân đối kế toán     45    tỷ     CK
# 484  Chỉ tiêu cân đối kế toán     46    tỷ     CK
# 485  Chỉ tiêu cân đối kế toán     47    tỷ     CK
# 486  Chỉ tiêu cân đối kế toán     48    tỷ     CK
# 487  Chỉ tiêu cân đối kế toán     49    tỷ     CK
# 488  Chỉ tiêu cân đối kế toán     50    tỷ     CK
# 489  Chỉ tiêu cân đối kế toán     51    tỷ     CK
# 490  Chỉ tiêu cân đối kế toán     52    tỷ     CK
# 491  Chỉ tiêu cân đối kế toán     53    tỷ     CK
# 492  Chỉ tiêu cân đối kế toán     54    tỷ     CK
# 493  Chỉ tiêu cân đối kế toán     55    tỷ     CK
# 494  Chỉ tiêu cân đối kế toán     56    tỷ     CK
# 495  Chỉ tiêu cân đối kế toán     57    tỷ     CK
# 496  Chỉ tiêu cân đối kế toán     58    tỷ     CK
# 497  Chỉ tiêu cân đối kế toán     59    tỷ     CK
# 498  Chỉ tiêu cân đối kế toán     60    tỷ     CK
# 499  Chỉ tiêu cân đối kế toán     61    tỷ     CK
# 500  Chỉ tiêu cân đối kế toán     62    tỷ     CK
# 501  Chỉ tiêu cân đối kế toán     63    tỷ     CK
# 502  Chỉ tiêu cân đối kế toán     64    tỷ     CK
# 503  Chỉ tiêu cân đối kế toán     65    tỷ     CK
# 504  Chỉ tiêu cân đối kế toán     66    tỷ     CK
# 505  Chỉ tiêu cân đối kế toán     67    tỷ     CK
# 506  Chỉ tiêu kết quả kinh doanh  1     tỷ     CT
# 507  Chỉ tiêu kết quả kinh doanh  3     tỷ     CT
# 508  Chỉ tiêu kết quả kinh doanh  4     %      CT
# 509  Chỉ tiêu khả năng sinh lợi   5     %      CT
# 510  Chỉ tiêu khả năng sinh lợi   6     %      CT
# 511  Chỉ tiêu khả năng sinh lợi   7     %      CT
# 512  Chỉ tiêu khả năng sinh lợi   8     %      CT
# 513  Chỉ tiêu khả năng sinh lợi   9     %      CT
# 514  Chỉ tiêu khả năng sinh lợi   10    %      CT
# 515  Chỉ tiêu định giá            12    index  CT
# 516  Chỉ tiêu định giá            13    index  CT
# 517  Chỉ tiêu định giá            14    index  CT
# 518  Chỉ tiêu định giá            15    index  CT
# 519  Chỉ tiêu định giá            16    index  CT
# 520  Chỉ tiêu định giá            17    index  CT
# 521  Chỉ tiêu định giá            18    index  CT
# 522  Chỉ tiêu định giá            19    triệu  CT
# 523  Chỉ tiêu định giá            20    tỷ     CT
# 524  Chỉ tiêu cân đối kế toán     21    tỷ     CT
# 525  Chỉ tiêu cân đối kế toán     22    tỷ     CT
# 526  Chỉ tiêu cân đối kế toán     23    tỷ     CT
# 527  Chỉ tiêu cân đối kế toán     24    tỷ     CT
# 528  Chỉ tiêu cân đối kế toán     25    tỷ     CT
# 529  Chỉ tiêu cân đối kế toán     26    tỷ     CT
# 530  Chỉ tiêu cân đối kế toán     27    tỷ     CT
# 531  Chỉ tiêu cân đối kế toán     28    tỷ     CT
# 532  Chỉ tiêu cân đối kế toán     29    tỷ     CT
# 533  Chỉ tiêu cơ cấu nguồn vốn    30    index  CT
# 534  Chỉ tiêu cơ cấu nguồn vốn    31    index  CT
# 535  Chỉ tiêu hiệu quả hoạt động  32    index  CT
# 536  Chỉ tiêu hiệu quả hoạt động  33    index  CT
# 537  Chỉ tiêu hiệu quả hoạt động  34    index  CT
# 538  Chỉ tiêu hiệu quả hoạt động  35    index  CT
# 539  Chỉ tiêu hiệu quả hoạt động  36    index  CT
# 540  Chỉ tiêu hiệu quả hoạt động  37    index  CT
# 541  Chỉ tiêu thanh khoản         38    index  CT
# 542  Chỉ tiêu thanh khoản         39    index  CT
# 543  Chỉ tiêu thanh khoản         40    index  CT
# 544  Chỉ tiêu thanh khoản         41    index  CT
# 545  Chỉ tiêu thanh khoản         42    index  CT
# 546  Chỉ tiêu lưu chuyển tiền tệ  43    tỷ     CT
# 547  Chỉ tiêu lưu chuyển tiền tệ  44    tỷ     CT
# 548  Chỉ tiêu cân đối kế toán     45    tỷ     CT
# 549  Chỉ tiêu cân đối kế toán     46    tỷ     CT
# 550  Chỉ tiêu cân đối kế toán     47    tỷ     CT
# 551  Chỉ tiêu cân đối kế toán     48    tỷ     CT
# 552  Chỉ tiêu cân đối kế toán     49    tỷ     CT
# 553  Chỉ tiêu cân đối kế toán     50    tỷ     CT
# 554  Chỉ tiêu cân đối kế toán     51    tỷ     CT
# 555  Chỉ tiêu cân đối kế toán     52    tỷ     CT
# 556  Chỉ tiêu cân đối kế toán     53    tỷ     CT
# 557  Chỉ tiêu cân đối kế toán     54    tỷ     CT
# 558  Chỉ tiêu cân đối kế toán     55    tỷ     CT
# 559  Chỉ tiêu cân đối kế toán     56    tỷ     CT
# 560  Chỉ tiêu cân đối kế toán     57    tỷ     CT
# 561  Chỉ tiêu cân đối kế toán     58    tỷ     CT
# 562  Chỉ tiêu cân đối kế toán     59    tỷ     CT
# 563  Chỉ tiêu cân đối kế toán     60    tỷ     CT
# 564  Chỉ tiêu cân đối kế toán     61    tỷ     CT
# 565  Chỉ tiêu cân đối kế toán     62    tỷ     CT
# 566  Chỉ tiêu cân đối kế toán     63    tỷ     CT
# 567  Chỉ tiêu cân đối kế toán     64    tỷ     CT
# 568  Chỉ tiêu cân đối kế toán     65    tỷ     CT
# 569  Chỉ tiêu cân đối kế toán     66    tỷ     CT
# 570  Chỉ tiêu cân đối kế toán     67    tỷ     CT
# 571  Chỉ tiêu kết quả kinh doanh  1     tỷ     NH
# 572  Chỉ tiêu kết quả kinh doanh  2     %      NH
# 573  Chỉ tiêu kết quả kinh doanh  3     tỷ     NH
# 574  Chỉ tiêu kết quả kinh doanh  4     %      NH
# 575  Chỉ tiêu khả năng sinh lợi   5     %      NH
# 576  Chỉ tiêu khả năng sinh lợi   6     %      NH
# 577  Chỉ tiêu khả năng sinh lợi   7     %      NH
# 578  Chỉ tiêu khả năng sinh lợi   8     %      NH
# 579  Chỉ tiêu khả năng sinh lợi   9     %      NH
# 580  Chỉ tiêu khả năng sinh lợi   10    %      NH
# 581  Chỉ tiêu định giá            12    index  NH
# 582  Chỉ tiêu định giá            13    index  NH
# 583  Chỉ tiêu định giá            14    index  NH
# 584  Chỉ tiêu định giá            15    index  NH
# 585  Chỉ tiêu định giá            16    index  NH
# 586  Chỉ tiêu định giá            17    index  NH
# 587  Chỉ tiêu định giá            18    index  NH
# 588  Chỉ tiêu định giá            19    triệu  NH
# 589  Chỉ tiêu định giá            20    tỷ     NH
# 590  Chỉ tiêu cân đối kế toán     21    tỷ     NH
# 591  Chỉ tiêu cân đối kế toán     22    tỷ     NH
# 592  Chỉ tiêu cân đối kế toán     23    tỷ     NH
# 593  Chỉ tiêu cân đối kế toán     24    tỷ     NH
# 594  Chỉ tiêu cân đối kế toán     25    tỷ     NH
# 595  Chỉ tiêu cân đối kế toán     26    tỷ     NH
# 596  Chỉ tiêu cân đối kế toán     27    tỷ     NH
# 597  Chỉ tiêu cân đối kế toán     28    tỷ     NH
# 598  Chỉ tiêu cân đối kế toán     29    tỷ     NH
# 599  Chỉ tiêu cơ cấu nguồn vốn    30    index  NH
# 600  Chỉ tiêu cơ cấu nguồn vốn    31    index  NH
# 601  Chỉ tiêu hiệu quả hoạt động  32    index  NH
# 602  Chỉ tiêu hiệu quả hoạt động  33    index  NH
# 603  Chỉ tiêu hiệu quả hoạt động  34    index  NH
# 604  Chỉ tiêu hiệu quả hoạt động  35    index  NH
# 605  Chỉ tiêu hiệu quả hoạt động  36    index  NH
# 606  Chỉ tiêu hiệu quả hoạt động  37    index  NH
# 607  Chỉ tiêu thanh khoản         38    index  NH
# 608  Chỉ tiêu thanh khoản         39    index  NH
# 609  Chỉ tiêu thanh khoản         40    index  NH
# 610  Chỉ tiêu thanh khoản         41    index  NH
# 611  Chỉ tiêu thanh khoản         42    index  NH
# 612  Chỉ tiêu lưu chuyển tiền tệ  43    tỷ     NH
# 613  Chỉ tiêu lưu chuyển tiền tệ  44    tỷ     NH
# 614  Chỉ tiêu cân đối kế toán     45    tỷ     NH
# 615  Chỉ tiêu cân đối kế toán     46    tỷ     NH
# 616  Chỉ tiêu cân đối kế toán     47    tỷ     NH
# 617  Chỉ tiêu cân đối kế toán     48    tỷ     NH
# 618  Chỉ tiêu cân đối kế toán     49    tỷ     NH
# 619  Chỉ tiêu cân đối kế toán     50    tỷ     NH
# 620  Chỉ tiêu cân đối kế toán     51    tỷ     NH
# 621  Chỉ tiêu cân đối kế toán     52    tỷ     NH
# 622  Chỉ tiêu cân đối kế toán     53    tỷ     NH
# 623  Chỉ tiêu cân đối kế toán     54    tỷ     NH
# 624  Chỉ tiêu cân đối kế toán     55    tỷ     NH
# 625  Chỉ tiêu cân đối kế toán     56    tỷ     NH
# 626  Chỉ tiêu cân đối kế toán     57    tỷ     NH
# 627  Chỉ tiêu cân đối kế toán     58    tỷ     NH
# 628  Chỉ tiêu cân đối kế toán     59    tỷ     NH
# 629  Chỉ tiêu cân đối kế toán     60    tỷ     NH
# 630  Chỉ tiêu cân đối kế toán     61    tỷ     NH
# 631  Chỉ tiêu cân đối kế toán     62    tỷ     NH
# 632  Chỉ tiêu kết quả kinh doanh  8     tỷ     CT
# 633  Chỉ tiêu cân đối kế toán     63    tỷ     NH
# 634  Chỉ tiêu cân đối kế toán     64    tỷ     NH
# 635  Chỉ tiêu cân đối kế toán     65    tỷ     NH
# 636  Chỉ tiêu cân đối kế toán     66    tỷ     NH
# 637  Chỉ tiêu cân đối kế toán     67    tỷ     NH
# 638  Chỉ tiêu kết quả kinh doanh  1     tỷ     BH
# 639  Chỉ tiêu kết quả kinh doanh  2     tỷ     BH
# 640  Chỉ tiêu kết quả kinh doanh  3     tỷ     BH
# 641  Chỉ tiêu kết quả kinh doanh  4     tỷ     BH
# 642  Chỉ tiêu kết quả kinh doanh  5     tỷ     BH
# 643  Chỉ tiêu kết quả kinh doanh  6     tỷ     BH
# 644  Chỉ tiêu kết quả kinh doanh  7     tỷ     BH
# 645  Chỉ tiêu kết quả kinh doanh  8     tỷ     BH
# 646  Chỉ tiêu kết quả kinh doanh  9     tỷ     BH
# 647  Chỉ tiêu kết quả kinh doanh  10    tỷ     BH
# 648  Chỉ tiêu kết quả kinh doanh  11    tỷ     BH
# 649  Chỉ tiêu kết quả kinh doanh  12    tỷ     BH
# 650  Chỉ tiêu kết quả kinh doanh  13    tỷ     BH
# 651  Chỉ tiêu kết quả kinh doanh  14    tỷ     BH
# 652  Chỉ tiêu kết quả kinh doanh  1     tỷ     CK
# 653  Chỉ tiêu kết quả kinh doanh  2     tỷ     CK
# 654  Chỉ tiêu kết quả kinh doanh  3     tỷ     CK
# 655  Chỉ tiêu kết quả kinh doanh  4     tỷ     CK
# 656  Chỉ tiêu kết quả kinh doanh  5     tỷ     CK
# 657  Chỉ tiêu kết quả kinh doanh  6     tỷ     CK
# 658  Chỉ tiêu kết quả kinh doanh  7     tỷ     CK
# 659  Chỉ tiêu kết quả kinh doanh  8     tỷ     CK
# 660  Chỉ tiêu kết quả kinh doanh  9     tỷ     CK
# 661  Chỉ tiêu kết quả kinh doanh  10    tỷ     CK
# 662  Chỉ tiêu kết quả kinh doanh  11    tỷ     CK
# 663  Chỉ tiêu kết quả kinh doanh  12    tỷ     CK
# 664  Chỉ tiêu kết quả kinh doanh  13    tỷ     CK
# 665  Chỉ tiêu kết quả kinh doanh  14    tỷ     CK
# 666  Chỉ tiêu kết quả kinh doanh  15    tỷ     CK
# 667  Chỉ tiêu kết quả kinh doanh  16    tỷ     CK
# 668  Chỉ tiêu kết quả kinh doanh  17    tỷ     CK
# 669  Chỉ tiêu kết quả kinh doanh  1     tỷ     CT
# 670  Chỉ tiêu kết quả kinh doanh  2     tỷ     CT
# 671  Chỉ tiêu kết quả kinh doanh  3     tỷ     CT
# 672  Chỉ tiêu kết quả kinh doanh  4     tỷ     CT
# 673  Chỉ tiêu kết quả kinh doanh  5     tỷ     CT
# 674  Chỉ tiêu kết quả kinh doanh  7     tỷ     CT
# 675  Chỉ tiêu kết quả kinh doanh  9     tỷ     CT
# 676  Chỉ tiêu kết quả kinh doanh  10    tỷ     CT
# 677  Chỉ tiêu kết quả kinh doanh  11    tỷ     CT
# 678  Chỉ tiêu kết quả kinh doanh  12    tỷ     CT
# 679  Chỉ tiêu kết quả kinh doanh  13    tỷ     CT
# 680  Chỉ tiêu kết quả kinh doanh  14    tỷ     CT
# 681  Chỉ tiêu kết quả kinh doanh  15    tỷ     CT
# 682  Chỉ tiêu kết quả kinh doanh  16    tỷ     CT
# 683  Chỉ tiêu kết quả kinh doanh  17    tỷ     CT
# 684  Chỉ tiêu kết quả kinh doanh  18    tỷ     CT
# 685  Chỉ tiêu kết quả kinh doanh  19    tỷ     CT
# 686  Chỉ tiêu kết quả kinh doanh  20    tỷ     CT
# 687  Chỉ tiêu kết quả kinh doanh  21    tỷ     CT
# 688  Chỉ tiêu kết quả kinh doanh  22    tỷ     CT
# 689  Chỉ tiêu kết quả kinh doanh  1     tỷ     NH
# 690  Chỉ tiêu kết quả kinh doanh  2     tỷ     NH
# 691  Chỉ tiêu kết quả kinh doanh  3     tỷ     NH
# 692  Chỉ tiêu kết quả kinh doanh  4     tỷ     NH
# 693  Chỉ tiêu kết quả kinh doanh  5     tỷ     NH
# 694  Chỉ tiêu kết quả kinh doanh  6     tỷ     NH
# 695  Chỉ tiêu kết quả kinh doanh  7     tỷ     NH
# 696  Chỉ tiêu kết quả kinh doanh  8     tỷ     NH
# 697  Chỉ tiêu kết quả kinh doanh  9     tỷ     NH
# 698  Chỉ tiêu kết quả kinh doanh  10    tỷ     NH
# 699  Chỉ tiêu kết quả kinh doanh  11    tỷ     NH
# 700  Chỉ tiêu kết quả kinh doanh  12    tỷ     NH
# 701  Chỉ tiêu kết quả kinh doanh  13    tỷ     NH
# 702  Chỉ tiêu kết quả kinh doanh  14    tỷ     NH
# 703  Chỉ tiêu kết quả kinh doanh  15    tỷ     NH
# 704  Chỉ tiêu kết quả kinh doanh  16    tỷ     NH
# 705  Chỉ tiêu kết quả kinh doanh  17    tỷ     NH
# 706  Chỉ tiêu kết quả kinh doanh  18    tỷ     NH
# 707  Chỉ tiêu kết quả kinh doanh  19    tỷ     NH
# 708  Chỉ tiêu kết quả kinh doanh  20    tỷ     NH
# 709  Chỉ tiêu kết quả kinh doanh  21    tỷ     NH
# 710  Chỉ tiêu kết quả kinh doanh  22    tỷ     NH
# 711  Chỉ tiêu kết quả kinh doanh  23    tỷ     NH
# 712  Chỉ tiêu kết quả kinh doanh  24    tỷ     NH
# 713  Chỉ tiêu kết quả kinh doanh  25    tỷ     NH
# 714  Chỉ tiêu khả năng sinh lợi   5     tỷ     BH
# 715  Chỉ tiêu khả năng sinh lợi   6     tỷ     BH
# 716  Chỉ tiêu khả năng sinh lợi   13    %      BH
# 717  Chỉ tiêu hiệu quả hoạt động  28    index  BH
# 718  Chỉ tiêu cơ cấu nguồn vốn    36    index  BH
# 719  Chỉ tiêu cơ cấu nguồn vốn    38    index  BH
# 720  Chỉ tiêu khả năng sinh lợi   5     tỷ     CK
# 721  Chỉ tiêu khả năng sinh lợi   6     tỷ     CK
# 722  Chỉ tiêu khả năng sinh lợi   13    %      CK
# 723  Chỉ tiêu hiệu quả hoạt động  28    index  CK
# 724  Chỉ tiêu cơ cấu nguồn vốn    36    index  CK
# 725  Chỉ tiêu cơ cấu nguồn vốn    38    index  CK
# 726  Chỉ tiêu khả năng sinh lợi   5     tỷ     CT
# 727  Chỉ tiêu khả năng sinh lợi   6     tỷ     CT
# 728  Chỉ tiêu khả năng sinh lợi   13    %      CT
# 729  Chỉ tiêu hiệu quả hoạt động  28    index  CT
# 730  Chỉ tiêu cơ cấu nguồn vốn    36    index  CT
# 731  Chỉ tiêu cơ cấu nguồn vốn    38    index  CT
# 732  Chỉ tiêu khả năng sinh lợi   5     tỷ     NH
# 733  Chỉ tiêu khả năng sinh lợi   6     tỷ     NH
# 734  Chỉ tiêu khả năng sinh lợi   13    %      NH
# 735  Chỉ tiêu hiệu quả hoạt động  28    index  NH
# 736  Chỉ tiêu cơ cấu nguồn vốn    36    index  NH
# 737  Chỉ tiêu cơ cấu nguồn vốn    38    index  NH

# %%
df_balance_sheet_full = pd.concat(dict_report_df['Balance Sheet'], axis = 0)
df_balance_sheet_full = df_balance_sheet_full[df_balance_sheet_full['account'] != 'index']
df_balance_sheet_full = pd.merge(df_balance_sheet_full, df_exchange_short, how = 'left', on='symbol')
df_balance_sheet_full['account_en'] = df_balance_sheet_full['account'].apply(lambda x: dict_balance_sheet_field[x])
df_balance_sheet_full['report_type'] = 'Balance Sheet'
df_balance_sheet_full = df_balance_sheet_full[['symbol', 'exchange', 'organ_name', 'report_type', 'report_date', 'account', 'account_en', 'value']]
# df_balance_sheet_full['account'] = df_balance_sheet_full.Categorical(df['account'], categories=list(dict_balance_sheet_field.keys()), ordered=True)
df_balance_sheet_full.sort_values(by=['symbol', 'report_date'], inplace = True)

# %%
dict_report_df.keys()
# Out:
# dict_keys(['Balance Sheet', 'Income Statement', 'Cash Flow Statement'])

# %%
df_income_statement_full = pd.concat(dict_report_df['Income Statement'], axis = 0)
df_income_statement_full = df_income_statement_full[df_income_statement_full['account'] != 'index']
df_income_statement_full = pd.merge(df_income_statement_full, df_exchange_short, how = 'left', on='symbol')
df_income_statement_full['account_en'] = df_income_statement_full['account'].apply(lambda x: dict_balance_sheet_field[x])
df_income_statement_full['report_type'] = 'Income Statement'
df_income_statement_full = df_income_statement_full[['symbol', 'exchange', 'organ_name', 'report_type', 'report_date', 'account', 'account_en', 'value']]
# df_income_statement_full['account'] = df_income_statement_full.Categorical(df['account'], categories=list(dict_balance_sheet_field.keys()), ordered=True)
df_income_statement_full.sort_values(by=['symbol', 'report_date'], inplace = True)
df_income_statement_full.columns = ['company_code', 'exchange', 'company_name', 'report_type', 'report_date', 'account', 'account_en', 'value']

# %%
df_cashflow_statement_full = pd.concat(dict_report_df['Cash Flow Statement'], axis = 0)
df_cashflow_statement_full = df_cashflow_statement_full[df_cashflow_statement_full['account'] != 'index']
df_cashflow_statement_full = pd.merge(df_cashflow_statement_full, df_exchange_short, how = 'left', on='symbol')
df_cashflow_statement_full['account_en'] = df_cashflow_statement_full['account'].apply(lambda x: dict_balance_sheet_field[x])
df_cashflow_statement_full['report_type'] = 'Cash Flow Statement'
df_cashflow_statement_full = df_cashflow_statement_full[['symbol', 'exchange', 'organ_name', 'report_type', 'report_date', 'account', 'account_en', 'value']]
# df_cashflow_statement_full['account'] = df_cashflow_statement_full.Categorical(df['account'], categories=list(dict_balance_sheet_field.keys()), ordered=True)
df_cashflow_statement_full.sort_values(by=['symbol', 'report_date'], inplace = True)
df_cashflow_statement_full.columns = ['company_code', 'exchange', 'company_name', 'report_type', 'report_date', 'account', 'account_en', 'value']

# %%
df_financical_statement = pd.concat([df_balance_sheet_full, df_income_statement_full, df_cashflow_statement_full], axis =0)

# %%
df_financical_statement.to_excel("Financial_Statement__ALL__SampleVNM.xlsx")

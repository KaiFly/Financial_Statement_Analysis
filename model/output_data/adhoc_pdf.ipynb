# %%
import pandas as pd
df  = pd.read_csv("final_financial_statements.csv", sep ="\t")

# %%
df.shape
# Out:
# (8096, 10)

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\SSID\\Project_ValuX\\Financial_Statement_Analysis\\model\\output_data'

# %%
# df[
#     (df['company_code'] == 'WSS')
#     & (df['report_date'] == 2015)
#     & (df['report_type'] == 'Balance Sheet')
# ]

# %%
df_load.to_parquet("final_financial_statements.parquet")

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\SSID\\Project_ValuX\\Financial_Statement_Analysis\\model\\output_data'

# %%
df_load = pd.read_parquet("all_financial_statements.parquet")

# %%
df_load.shape
# Out:
# (1408945, 10)

# %%
df_load.report_type.value_counts()
# Out:
# report_type
# Balance Sheet          5236
# Cash Flow Statement    1848
# Income Statement       1012
# Name: count, dtype: int64

# %%
financial_statement_schemas = ['company_code', 'exchange', 'company_name', 'industry', 'report_type', 'report_date', 'account', 'value', 'account_vi', 'account_en']
df_load.columns = financial_statement_schemas

# %%
df_load = pd.read_parquet('C:\\Users\\user\\Desktop\\SSID\\Project_ValuX\\Financial_Statement_Analysis\\apps\\data\\Financial_Statement__Full_Company_L10Y.parquet')

# %%
df_load['company_code']
# Out:
# 0          AAA
# 1          AAA
# 2          AAA
# 3          AAA
# 4          AAA
#           ...
# 1408963    YEG
# 1408964    YEG
# 1408965    YEG
# 1408966    YEG
# 1408967    YEG
# Name: company_code, Length: 1408968, dtype: object

# %%
import os
import logging
import datetime
import json
import argparse
import pandas as pd
from vnstock import Listing
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# ==============================================================================
# CONFIGURATION - THAY ĐỔI CÁC THAM SỐ TẠI ĐÂY
# ==============================================================================
CONFIG = {
    "start_year": 2015,
    "max_workers": 4,  # Số luồng chạy song song
    "output_dir": "output_data",
    "company_list_filename": "company_list.csv",
    "raw_data_filename": "raw_financials.parquet",
    "final_data_filename": "final_financial_statements.parquet",
    "final_data_filename_csv": "final_financial_statements.csv",
    "mapping_filepath": "account_mapping.json"
}
financial_statement_schemas = ['company_code', 'exchange', 'company_name', 'industry', 'report_type', 'report_date', 'account', 'value', 'account_vi', 'account_en']

# ==============================================================================
# LOGIC SCRAPING (CLASS) - PHIÊN BẢN ĐÃ SỬA LỖI
# ==============================================================================
class CafeFScraper:
    """Scrapes financial statements for a single company from cafef.vn."""
    BASE_URL = "https://s.cafef.vn/bao-cao-tai-chinh/{}/{}/{}/0/0/0/0/bao-cao-tai-chinh.chn"
    REPORT_TYPES = ['bsheet', 'incsta', 'cashflow']

    def __init__(self, symbol: str, start_year: int):
        self.symbol = symbol.upper()
        self.start_year = start_year
        self.end_year = datetime.datetime.now().year

    def _fetch_report_table(self, report_type: str, year: int) -> pd.DataFrame | None:
        """
        Fetches the entire financial report table for a given year.
        Returns the specific DataFrame table, or None if it fails.
        """
        url = self.BASE_URL.format(self.symbol, report_type, year)
        try:
            web_data = pd.read_html(url)
            # The actual data is usually in the 5th table (index 4)
            table = web_data[4] 
            # Check if the table is meaningful (has more than 1 row and 1 column)
            if table.shape[0] > 1 and table.shape[1] > 1:
                return table
            return None
        except Exception as e:
            logging.debug(f"Could not fetch or parse table from {url}. Error: {e}")
            return None

    def scrape_all_reports(self) -> pd.DataFrame | None:
        """
        Scrapes all three report types (BS, IS, CF) for all years for the company.
        This version is more resilient to missing data for the most recent year.
        """
        company_reports = []
        report_map = {'bsheet': 'Balance Sheet',
                      'incsta': 'Income Statement',
                      'cashflow': 'Cash Flow Statement',
                      'cashflowdirect': 'Direct Cash Flow Statement'
                     }
        
        for report_type in self.REPORT_TYPES:
            # Step 1: Fetch all available yearly tables first
            yearly_tables = {}
            for year in range(self.start_year, self.end_year + 1):
                table = self._fetch_report_table(report_type, year)
                if table is not None:
                    yearly_tables[year] = table
            
            # Step 2: If no data was found for any year, skip this report type
            if not yearly_tables:
                logging.debug(f"No data found for {self.symbol} - {report_type} in any year.")
                continue

            # Step 3: Get categories from the first successfully fetched table
            # Categories (account names) are in the first column (iloc[:, 0])
            first_available_table = list(yearly_tables.values())[0]
            categories = first_available_table.iloc[:, 0]

            # Step 4: Extract the actual data column from each fetched table
            # Data is in the 5th column (iloc[:, 4])
            yearly_data = {
                year: table.iloc[:, 4]
                for year, table in yearly_tables.items()
            }
            
            # Step 5: Construct the DataFrame for this report type
            df_wide = pd.DataFrame(yearly_data)
            df_wide['account'] = categories
            df_long = df_wide.melt(id_vars=['account'], var_name='report_date', value_name='value')
            df_long['report_type'] = report_map.get(report_type)
            company_reports.append(df_long)
        
        if not company_reports: 
            return None
            
        final_df = pd.concat(company_reports, ignore_index=True)
        final_df['symbol'] = self.symbol
        return final_df
# ==============================================================================
# LOGIC HELPER (FUNCTIONS)
# ==============================================================================
def get_company_listing() -> pd.DataFrame:
    """Fetches a list of companies from HSX and HNX."""
    logging.info("Fetching company list...")
    listing = Listing()
    df_symbols = listing.symbols_by_exchange()
    df_short = df_symbols[df_symbols['exchange'].isin(['HSX', 'HNX']) & (df_symbols['type'] == 'STOCK')]
    
    df_industries = listing.symbols_by_industries()
    df_industry_names = df_industries[['symbol', 'icb_name2']].rename(columns={'icb_name2': 'industry'})
    
    df_final = pd.merge(df_short, df_industry_names, how='left', on='symbol')
    return df_final[['symbol', 'exchange', 'organ_name', 'industry']].dropna(subset=['symbol'])

def transform_data(raw_df: pd.DataFrame, company_info_df: pd.DataFrame, mapping_dict: dict) -> pd.DataFrame:
    """Cleans and transforms raw scraped data."""
    logging.info("Transforming raw data...")
    df = pd.merge(raw_df, company_info_df, on='symbol', how='left')
    df.dropna(subset=['symbol', 'report_date', 'account'], inplace=True)
    df['value'] = pd.to_numeric(df['value'], errors='coerce')
    df['report_date'] = df['report_date'].astype(str)
    
    df['account_vi'] = df['account']
    df['account_en'] = df['account'].apply(lambda x: mapping_dict.get(x, {}).get('english'))
    df['account'] = df['account'].apply(lambda x: mapping_dict.get(x, {}).get('english_format'))
    
    final_cols = ['symbol', 'exchange', 'organ_name', 'industry', 'report_type', 'report_date', 'account', 'value', 'account_vi', 'account_en']
    return df[final_cols].sort_values(by=['symbol', 'report_type', 'report_date'])

# %%
output_dir = CONFIG['output_dir']
os.makedirs(output_dir, exist_ok=True)

# --- Step 1: Get Company List ---
try:
    company_df = get_company_listing()
    company_list_path = os.path.join(output_dir, CONFIG['company_list_filename'])
    company_df.to_csv(company_list_path, index=False)
    logging.info(f"Saved company list of {len(company_df)} companies to {company_list_path}")
except:
    company_df = pd.read_csv(company_list_path)

# --- Step 2: Scrape Data Concurrently ---
symbols_to_scrape = company_df['symbol'].tolist()

# %%
symbols_to_scrape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 symbols_to_scrape
#
# NameError: name 'symbols_to_scrape' is not defined

# %%
all_results = []
with ThreadPoolExecutor(max_workers=CONFIG['max_workers']) as executor:
    future_to_symbol = {
        executor.submit(CafeFScraper(symbol, CONFIG['start_year']).scrape_all_reports): symbol
        for symbol in symbols_to_scrape
    }
    progress = tqdm(as_completed(future_to_symbol), total=len(symbols_to_scrape), desc="Scraping Financials")
    for future in progress:
        result_df = future.result()
        if result_df is not None:
            all_results.append(result_df)

if not all_results:
    logging.warning("Scraping finished, but no data was collected.")
    return

raw_df = pd.concat(all_results, ignore_index=True)
raw_data_path = os.path.join(output_dir, CONFIG['raw_data_filename'])
# raw_df.to_parquet(raw_data_path, index=False)
logging.info(f"Saved raw scraped data to {raw_data_path}")

# --- Step 3: Transform Data ---
with open(CONFIG['mapping_filepath'], 'r', encoding='utf-8') as f:
    account_map = json.load(f)
    
final_df = transform_data(raw_df, company_df, account_map)
final_df.columns = financial_statement_schemas
final_data_path = os.path.join(output_dir, CONFIG['final_data_filename'])
final_csv_data_path = os.path.join(output_dir, CONFIG['final_data_filename_csv'])

# add conversion here for parquet saving
# final_df.value = final_df.value.astype(float)
final_df.to_csv(final_csv_data_path, sep="\t", index=False)
final_df.to_parquet(final_data_path, index=False)

logging.info(f"Successfully transformed data and saved to {final_data_path}")
logging.info("Pipeline finished.")
# Out:
# Scraping Financials: 100%|█████████████████████████████████████████████████████████| 696/696 [5:08:56<00:00, 26.63s/it]
#   Cell In[14], line 15
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
all_results
# Out:
# []

# %%
company_df = pd.read_csv(company_list_path)

# %%
list_company = list(set(company_df.symbol))

# %%
import os
import requests
from urllib.parse import urlparse

OUTPUT_FOLDER = "vietstock_reports_hnx"
# --- Main Script ---
def download_financial_reports(tickers, output_dir):
    """
    Downloads financial reports for a list of company tickers.

    Args:
        tickers (list): A list of company ticker strings.
        output_dir (str): The name of the folder to save files to.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"Created directory: '{output_dir}'")

    # The base URL structure. The '{}' is a placeholder for the company ticker.
    url_template = "https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/{}_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf"

    session = requests.Session()
    # Add a user-agent header to mimic a real browser request
    session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    })

    print("\n--- Starting Download Process ---")

    for company_ticker in tickers:
        # Format the URL with the current company ticker
        file_url = url_template.format(company_ticker)

        # Generate a local file path
        # We can get the filename directly from the URL
        filename = os.path.basename(urlparse(file_url).path)
        local_filepath = os.path.join(output_dir, filename)

        print(f"\nProcessing Ticker: {company_ticker}")
        print(f" -> URL: {file_url}")

        try:
            # Make the GET request to download the file
            # stream=True is important for downloading large files efficiently
            response = session.get(file_url, stream=True, timeout=30)

            # Check if the request was successful (HTTP status code 200)
            if response.status_code == 200:
                # Open the local file in binary write mode
                with open(local_filepath, 'wb') as f:
                    # Write the content of the response to the file in chunks
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f" ✔ Success: Report saved to '{local_filepath}'")
            else:
                # If the status code is not 200, the file likely doesn't exist or there was an error
                print(f" ❌ Failed: Could not download file. Server responded with status code {response.status_code}.")

        except requests.exceptions.RequestException as e:
            # Handle network-related errors (e.g., connection timeout)
            print(f" ❌ Error: A network error occurred for {company_ticker}. Details: {e}")

    print("\n--- Download Process Finished ---")


# download_financial_reports(list_company, OUTPUT_FOLDER)

# %%
download_financial_reports(list_company, OUTPUT_FOLDER)
# Out:
# Created directory: 'vietstock_reports_hnx'
#
# --- Starting Download Process ---
#
# Processing Ticker: PHR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PHR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TBX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TBX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BNA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BNA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BKC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BKC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DCM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DCM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PVI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PVI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HBS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HBS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VNF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VNF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: EVS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/EVS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: EVF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/EVF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KSB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KSB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SGT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SGT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ATS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ATS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: IPA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/IPA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: S99
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/S99_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DRL
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DRL_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NKG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NKG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TPB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TPB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PV2
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PV2_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ADC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ADC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KTS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KTS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HU1
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HU1_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PVG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PVG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GVR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GVR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CSC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CSC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HOM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HOM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: C47
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/C47_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BMC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BMC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CMG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CMG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KBC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KBC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SGH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SGH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NLG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NLG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: D11
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/D11_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BVS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BVS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VJC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VJC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NBW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NBW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PVP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PVP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HCT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HCT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: APS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/APS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BTT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BTT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SMT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SMT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SBT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SBT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TDT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TDT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TDW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TDW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VPS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VPS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NAG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NAG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NAB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NAB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NBC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NBC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TMS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TMS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SFG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SFG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ILB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ILB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CCI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CCI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DIH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DIH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VAF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VAF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MKV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MKV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BTP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BTP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SPM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SPM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VIB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VIB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HAT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HAT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: UIC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/UIC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BST
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BST_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SIP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SIP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SLS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SLS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VE3
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VE3_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TXM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TXM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: OCH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/OCH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TIX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TIX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DGW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DGW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PTX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PTX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HII
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HII_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MAS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MAS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: REE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/REE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CPC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CPC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CEO
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CEO_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: C32
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/C32_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: AGR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/AGR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CTD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CTD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PVS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PVS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ✔ Success: Report saved to 'vietstock_reports_hnx\PVS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf'
#
# Processing Ticker: SGR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SGR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NTP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NTP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BTW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BTW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DTD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DTD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CLC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CLC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TYA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TYA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HAG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HAG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KHS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KHS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HVT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HVT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VHL
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VHL_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VFS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VFS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MIG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MIG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VNE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VNE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TMP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TMP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DXV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DXV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NHT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NHT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BAX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BAX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TMB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TMB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ONE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ONE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SAV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SAV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KDH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KDH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ICG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ICG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PGI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PGI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KDM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KDM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SBV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SBV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PCE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PCE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SBG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SBG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TPP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TPP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CTF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CTF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: FCN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/FCN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: D2D
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/D2D_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VGC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VGC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TMC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TMC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DC4
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DC4_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TD6
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TD6_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VSH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VSH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PSI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PSI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PSD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PSD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TVS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TVS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TLD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TLD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HAH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HAH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: V12
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/V12_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SGC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SGC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SJS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SJS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ACG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ACG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PGC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PGC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CTI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CTI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VPI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VPI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VLA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VLA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SCI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SCI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BIC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BIC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TTF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TTF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MCP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MCP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VIT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VIT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HMC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HMC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TCD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TCD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GKM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GKM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BAF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BAF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VNS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VNS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TOT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TOT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: STG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/STG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PSW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PSW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VNC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VNC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VTH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VTH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DRH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DRH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DPR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DPR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SFN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SFN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VHC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VHC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ACB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ACB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SSB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SSB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CET
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CET_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SCR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SCR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HTN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HTN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DAE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DAE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HLC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HLC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GSP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GSP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SMN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SMN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VSA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VSA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HPG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HPG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NT2
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NT2_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NET
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NET_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PRE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PRE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NSC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NSC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: LGL
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/LGL_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: IMP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/IMP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SHP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SHP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VND
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VND_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DPM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DPM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HRC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HRC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PMC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PMC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: L40
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/L40_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HTI
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HTI_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TIG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TIG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TCR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TCR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: L18
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/L18_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DSE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DSE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GEX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GEX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TLH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TLH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: AAT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/AAT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HJS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HJS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ✔ Success: Report saved to 'vietstock_reports_hnx\HJS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf'
#
# Processing Ticker: DHT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DHT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CTR
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CTR_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ACC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ACC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HGM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HGM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: LHG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/LHG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KOS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KOS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VIP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VIP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VDS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VDS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ABS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ABS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: QHD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/QHD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: LCG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/LCG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HCD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HCD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NBP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NBP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DBT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DBT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: ADG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/ADG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SSM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SSM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CMS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CMS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: THD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/THD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CTG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CTG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CLW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CLW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BED
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BED_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SEB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SEB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DTK
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DTK_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VC6
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VC6_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: FCM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/FCM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HTC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HTC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: FTS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/FTS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: BKG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/BKG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: INN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/INN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GLT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GLT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TMT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TMT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VTV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VTV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VOS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VOS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TNT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TNT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PMP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PMP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VC2
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VC2_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ✔ Success: Report saved to 'vietstock_reports_hnx\VC2_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf'
#
# Processing Ticker: SJE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SJE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SC5
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SC5_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MBB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MBB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: THT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/THT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
# ...
#
# Processing Ticker: APH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/APH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CX8
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CX8_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PMB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PMB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TKU
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TKU_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CCC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CCC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MST
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MST_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HAP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HAP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CJC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CJC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DSN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DSN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PCH
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PCH_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DBD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DBD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PVT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PVT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MWG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MWG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PGV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PGV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: THS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/THS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SDC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SDC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PCT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PCT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: YEG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/YEG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VPB
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VPB_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PPT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PPT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CAN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CAN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VHM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VHM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VMD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VMD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VFG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VFG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TV4
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TV4_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: FDC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/FDC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: EVG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/EVG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PPS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PPS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CIA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CIA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: X20
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/X20_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DP3
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DP3_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: WSS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/WSS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: POW
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/POW_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DIG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DIG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DTT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DTT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MCO
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MCO_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PLX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PLX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HSL
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HSL_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: INC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/INC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MDC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MDC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: CLM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/CLM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HTV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HTV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DVP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DVP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SDG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SDG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ✔ Success: Report saved to 'vietstock_reports_hnx\SDG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf'
#
# Processing Ticker: PPC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PPC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MIC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MIC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SCG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SCG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VCF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VCF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: AMV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/AMV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VIF
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VIF_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: QNP
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/QNP_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: STC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/STC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: PAN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/PAN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: LBM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/LBM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VBC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VBC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SDA
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SDA_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TSC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TSC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: MDG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/MDG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: AMC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/AMC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: RYG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/RYG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DVM
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DVM_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: S4A
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/S4A_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: GMX
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GMX_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DXS
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DXS_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VID
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VID_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: NDN
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/NDN_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TTT
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TTT_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: TTC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/TTC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VPG
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VPG_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: VHE
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/VHE_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: SJ1
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/SJ1_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ✔ Success: Report saved to 'vietstock_reports_hnx\SJ1_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf'
#
# Processing Ticker: GIC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/GIC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: KSV
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/KSV_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DST
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DST_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: HAD
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/HAD_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# Processing Ticker: DBC
#  -> URL: https://static2.vietstock.vn/data/HNX/2024/BCTC/VN/NAM/DBC_Baocaotaichinh_2024_Kiemtoan_Congtyme.pdf
#  ❌ Failed: Could not download file. Server responded with status code 404.
#
# --- Download Process Finished ---
